# %% [markdown]
# # Download OpenAlex data
#
# This notebook downloads the OpenAlex data for the ORKG project.

# %%
import os

base_dir = "data/orkg/"

# %%
import json

# Read name.json data in directory
def read_json(filename: str):
    json_file = os.path.join(filename)
    with open(json_file) as f:
        img_annotations = json.load(f)

    return img_annotations


# Pretty print json data to console
def print_json(tag: str, data: any):
    print(tag, json.dumps(data, indent=2, sort_keys=True))


# Pretty print json data to file
def write_json(filename: str, data: any):
    with open(filename, "w") as file:
        json.dump(data, file, indent=2, sort_keys=True)

# %%
import pandas as pd

meta_infos_raw = read_json(os.path.join(base_dir, "meta_infos.json"))
meta_infos = pd.DataFrame.from_dict(meta_infos_raw)
meta_infos
# Out:
#                                                   author  \
# 0                                        [J Wu, H Huang]
# 1                      [William A Sethares, Chih-Yu Wen]
# 2                     [A William, Sethares, Chih-Yu Wen]
# 3       [Xiaozong Yang, Yoohwan Kim, Ling Wang, Yan Jin]
# 4                            [A Savvides, R Virrankoski]
# ...                                                  ...
# 26838                                        David Nolte
# 26839                     [Rath, M, Marci-Boehncke, G. ]
# 26840  [Anja Pielsticker, K. Keller, Henrike Friedric...
# 26841  [Niels Brüggen, Valerie Jochim, A. Oberlinner,...
# 26842                               [Gimmler, R, Six, U]
#
#                                 doi paper_ids publication month  \
# 0       10.1109/vetecf.2005.1558414    R26672
# 1              10.1155/wcn.2005.686    R26676                12
# 2         10.1109/jsen.2013.2249659    R26679
# 3      10.1016/j.comnet.2007.10.005    R26682                 2
# 4        10.1109/mahss.2005.1542850    R26687
# ...                             ...       ...               ...
# 26838     10.1026/2191-9186/a000176   R576013                10
# 26839                                 R576016
# 26840                                 R576018
# 26841                                 R576020
# 26842   10.1007/978-3-658-28538-8_2   R576022
#
#       publication year      publisher  \
# 0                 2005
# 1                 2005
# 2                 2013
# 3                 2008
# 4
# ...                ...            ...
# 26838             2014  Frühe Bildung
# 26839             2013
# 26840             2012
# 26841             2018
# 26842             2007
#
#                                                    title  \
# 0      A probabilistic clustering algorithm in wirele...
# 1      Automatic Decentralized Clustering for Wireles...
# 2      Distributed clustering with directional antenn...
# 3      EEMC: An energy-efficient multi-level clusteri...
# 4      TASC: topology adaptive spatial clustering for...
# ...                                                  ...
# 26838  Eine Frage der Medienkompetenz?: Bedingungen m...
# 26839  Kinder-Medien-Bildung: eine Studie zu Medienko...
# 26840  Chancen und Potenziale digitaler Medien zur Um...
# 26841  Digitale Medien in Kindertageseinrichtungen: M...
# 26842  Die Förderung von Medienkompetenz im Kindergar...
#
#                                                url
# 0
# 1
# 2
# 3
# 4
# ...                                            ...
# 26838  http://dx.doi.org/10.1026/2191-9186/a000176
# 26839
# 26840
# 26841
# 26842
#
# [26843 rows x 8 columns]

# %%
import sqlite3

database_path = os.path.join(base_dir, "datalake.db")

# Open a connection to the SQLite database file
db = sqlite3.connect(database_path)

# Create a cursor object to execute SQL statements
cursor = db.cursor()

# %%
cursor.execute("CREATE TABLE IF NOT EXISTS openalex (id INTEGER PRIMARY KEY, title TEXT, data JSON)")

def openalex_exists(title: str):
    cursor.execute("SELECT * FROM openalex WHERE title = ?",
                   (title,))
    rows = cursor.fetchall()
    return len(rows) > 0


def store_openalex_data(title: str, data: dict):
    cursor.execute("INSERT INTO openalex (title, data) VALUES (?, ?)",
                   (title, json.dumps(data)))
    db.commit()

# %%
from pyalex import Works

title = "Automatic Decentralized Clustering for Wireless Sensor Networks"
# Causes error with ','
# title = "Purification, Characterization, and Gene Analysis of a Chitosanase"

openalex_data = Works().search_filter(title=title).get()
print_json("openalex_data", openalex_data)
# Out:
# openalex_data [
#   {
#     "abstract_inverted_index": {
#       "Each": [
#         14
#       ],
#       "Simplified": [
#         62
#       ],
#       "The": [
#         38,
#         82
#       ],
#       "We": [
#         0
#       ],
#       "a": [
#         2,
#         17,
#         29,
#         35,
#         42,
#         60
#       ],
#       "ad": [
#         8
#       ],
#       "algorithm": [
#         4,
#         39,
#         79,
#         86
#       ],
#       "an": [
#         7
#       ],
#       "analytically": [
#         89
#       ],
#       "and": [
#         21,
#         48,
#         73,
#         90
#       ],
#       "are": [
#         64,
#         80
#       ],
#       "asynchronously,": [
#         47
#       ],
#       "be": [
#         58
#       ],
#       "centralized": [
#         43
#       ],
#       "cluster": [
#         31
#       ],
#       "cluster.": [
#         37
#       ],
#       "clusters": [
#         71
#       ],
#       "clusters.": [
#         13
#       ],
#       "controller,": [
#         44
#       ],
#       "criteria": [
#         23
#       ],
#       "current": [
#         36
#       ],
#       "decentralized": [
#         3
#       ],
#       "described": [
#         88
#       ],
#       "determine": [
#         25
#       ],
#       "does": [
#         49
#       ],
#       "energy": [
#         75
#       ],
#       "estimate": [
#         67
#       ],
#       "for": [
#         5
#       ],
#       "form": [
#         28
#       ],
#       "formed,": [
#         72
#       ],
#       "hoc": [
#         9
#       ],
#       "into": [
#         12
#       ],
#       "investigated.": [
#         81
#       ],
#       "is": [
#         87
#       ],
#       "it": [
#         45
#       ],
#       "join": [
#         34
#       ],
#       "known": [
#         59
#       ],
#       "local": [
#         22
#       ],
#       "location": [
#         54
#       ],
#       "models": [
#         63
#       ],
#       "network": [
#         11
#       ],
#       "new": [
#         30
#       ],
#       "not": [
#         50
#       ],
#       "number": [
#         69
#       ],
#       "of": [
#         55,
#         70,
#         77,
#         84
#       ],
#       "operates": [
#         40,
#         46
#       ],
#       "or": [
#         32
#       ],
#       "organizing": [
#         6
#       ],
#       "performance": [
#         83
#       ],
#       "priori.": [
#         61
#       ],
#       "propose": [
#         1
#       ],
#       "random": [
#         18
#       ],
#       "require": [
#         51
#       ],
#       "requirements": [
#         76
#       ],
#       "sensor": [
#         10,
#         15
#       ],
#       "sensors": [
#         57
#       ],
#       "simulation.": [
#         92
#       ],
#       "that": [
#         52
#       ],
#       "the": [
#         53,
#         56,
#         68,
#         74,
#         78,
#         85
#       ],
#       "timer": [
#         20
#       ],
#       "to": [
#         24,
#         27,
#         33,
#         66
#       ],
#       "used": [
#         65
#       ],
#       "uses": [
#         16
#       ],
#       "via": [
#         91
#       ],
#       "waiting": [
#         19
#       ],
#       "whether": [
#         26
#       ],
#       "without": [
#         41
#       ]
#     },
#     "apc_list": {
#       "currency": "GBP",
#       "provenance": "doaj",
#       "value": 1140,
#       "value_usd": 1398
#     },
#     "apc_paid": {
#       "currency": "GBP",
#       "provenance": "doaj",
#       "value": 1140,
#       "value_usd": 1398
#     },
#     "authorships": [
#       {
#         "author": {
#           "display_name": "Chih-Yu Wen",
#           "id": "https://openalex.org/A2142907911",
#           "orcid": "https://orcid.org/0000-0001-6007-9361"
#         },
#         "author_position": "first",
#         "institutions": [
#           {
#             "country_code": "US",
#             "display_name": "University of Wisconsin\u2013Madison",
#             "id": "https://openalex.org/I135310074",
#             "ror": "https://ror.org/01y2jtd41",
#             "type": "education"
#           }
#         ],
#         "is_corresponding": true,
#         "raw_affiliation_string": "Department of Electrical and Computer Engineering, University of Wisconsin-Madison, USA",
#         "raw_affiliation_strings": [
#           "Department of Electrical and Computer Engineering, University of Wisconsin-Madison, USA"
#         ]
#       },
#       {
#         "author": {
#           "display_name": "William A. Sethares",
#           "id": "https://openalex.org/A4355826881",
#           "orcid": null
#         },
#         "author_position": "last",
#         "institutions": [
#           {
#             "country_code": "US",
#             "display_name": "University of Wisconsin\u2013Madison",
#             "id": "https://openalex.org/I135310074",
#             "ror": "https://ror.org/01y2jtd41",
#             "type": "education"
#           }
#         ],
#         "is_corresponding": false,
#         "raw_affiliation_string": "Department of Electrical and Computer Engineering, University of Wisconsin-Madison, USA",
#         "raw_affiliation_strings": [
#           "Department of Electrical and Computer Engineering, University of Wisconsin-Madison, USA"
#         ]
#       }
#     ],
#     "best_oa_location": {
#       "is_oa": true,
#       "landing_page_url": "https://doi.org/10.1155/wcn.2005.686",
#       "license": "cc-by",
#       "pdf_url": null,
#       "source": {
#         "display_name": "Eurasip Journal on Wireless Communications and Networking",
#         "host_organization": "https://openalex.org/P4310319965",
#         "host_organization_lineage": [
#           "https://openalex.org/P4310319965"
#         ],
#         "host_organization_lineage_names": [
#           "Springer Nature"
#         ],
#         "host_organization_name": "Springer Nature",
#         "id": "https://openalex.org/S82675988",
#         "is_in_doaj": true,
#         "is_oa": true,
#         "issn": [
#           "1687-1499",
#           "1687-1472"
#         ],
#         "issn_l": "1687-1472",
#         "type": "journal"
#       },
#       "version": "publishedVersion"
#     },
#     "biblio": {
#       "first_page": null,
#       "issue": "5",
#       "last_page": null,
#       "volume": "2005"
#     },
#     "cited_by_api_url": "https://api.openalex.org/works?filter=cites:W2124578313",
#     "cited_by_count": 58,
#     "concepts": [
#       {
#         "display_name": "Computer science",
#         "id": "https://openalex.org/C41008148",
#         "level": 0,
#         "score": 0.9078791,
#         "wikidata": "https://www.wikidata.org/wiki/Q21198"
#       },
#       {
#         "display_name": "Wireless sensor network",
#         "id": "https://openalex.org/C24590314",
#         "level": 2,
#         "score": 0.7792187,
#         "wikidata": "https://www.wikidata.org/wiki/Q336038"
#       },
#       {
#         "display_name": "Timer",
#         "id": "https://openalex.org/C2776633867",
#         "level": 3,
#         "score": 0.76310265,
#         "wikidata": "https://www.wikidata.org/wiki/Q186612"
#       },
#       {
#         "display_name": "Cluster analysis",
#         "id": "https://openalex.org/C73555534",
#         "level": 2,
#         "score": 0.63806325,
#         "wikidata": "https://www.wikidata.org/wiki/Q622825"
#       },
#       {
#         "display_name": "A priori and a posteriori",
#         "id": "https://openalex.org/C75553542",
#         "level": 2,
#         "score": 0.58443236,
#         "wikidata": "https://www.wikidata.org/wiki/Q178161"
#       },
#       {
#         "display_name": "Cluster (spacecraft)",
#         "id": "https://openalex.org/C164866538",
#         "level": 2,
#         "score": 0.561533,
#         "wikidata": "https://www.wikidata.org/wiki/Q367351"
#       },
#       {
#         "display_name": "Wireless ad hoc network",
#         "id": "https://openalex.org/C94523657",
#         "level": 3,
#         "score": 0.5276605,
#         "wikidata": "https://www.wikidata.org/wiki/Q4085781"
#       },
#       {
#         "display_name": "Controller (irrigation)",
#         "id": "https://openalex.org/C203479927",
#         "level": 2,
#         "score": 0.525332,
#         "wikidata": "https://www.wikidata.org/wiki/Q5165939"
#       },
#       {
#         "display_name": "Distributed computing",
#         "id": "https://openalex.org/C120314980",
#         "level": 1,
#         "score": 0.48872852,
#         "wikidata": "https://www.wikidata.org/wiki/Q180634"
#       },
#       {
#         "display_name": "Decentralised system",
#         "id": "https://openalex.org/C205875254",
#         "level": 3,
#         "score": 0.43773267,
#         "wikidata": "https://www.wikidata.org/wiki/Q17156857"
#       },
#       {
#         "display_name": "Energy (signal processing)",
#         "id": "https://openalex.org/C186370098",
#         "level": 2,
#         "score": 0.4330266,
#         "wikidata": "https://www.wikidata.org/wiki/Q442787"
#       },
#       {
#         "display_name": "Real-time computing",
#         "id": "https://openalex.org/C79403827",
#         "level": 1,
#         "score": 0.37800854,
#         "wikidata": "https://www.wikidata.org/wiki/Q3988"
#       },
#       {
#         "display_name": "Computer network",
#         "id": "https://openalex.org/C31258907",
#         "level": 1,
#         "score": 0.33722636,
#         "wikidata": "https://www.wikidata.org/wiki/Q1301371"
#       },
#       {
#         "display_name": "Wireless",
#         "id": "https://openalex.org/C555944384",
#         "level": 2,
#         "score": 0.27418622,
#         "wikidata": "https://www.wikidata.org/wiki/Q249"
#       },
#       {
#         "display_name": "Control (management)",
#         "id": "https://openalex.org/C2775924081",
#         "level": 2,
#         "score": 0.26078638,
#         "wikidata": "https://www.wikidata.org/wiki/Q55608371"
#       },
#       {
#         "display_name": "Artificial intelligence",
#         "id": "https://openalex.org/C154945302",
#         "level": 1,
#         "score": 0.13835669,
#         "wikidata": "https://www.wikidata.org/wiki/Q11660"
#       },
#       {
#         "display_name": "Telecommunications",
#         "id": "https://openalex.org/C76155785",
#         "level": 1,
#         "score": 0.08904117,
#         "wikidata": "https://www.wikidata.org/wiki/Q418"
#       },
#       {
#         "display_name": "Philosophy",
#         "id": "https://openalex.org/C138885662",
#         "level": 0,
#         "score": 0.0,
#         "wikidata": "https://www.wikidata.org/wiki/Q5891"
#       },
#       {
#         "display_name": "Statistics",
#         "id": "https://openalex.org/C105795698",
#         "level": 1,
#         "score": 0.0,
#         "wikidata": "https://www.wikidata.org/wiki/Q12483"
#       },
#       {
#         "display_name": "Mathematics",
#         "id": "https://openalex.org/C33923547",
#         "level": 0,
#         "score": 0.0,
#         "wikidata": "https://www.wikidata.org/wiki/Q395"
#       },
#       {
#         "display_name": "Epistemology",
#         "id": "https://openalex.org/C111472728",
#         "level": 1,
#         "score": 0.0,
#         "wikidata": "https://www.wikidata.org/wiki/Q9471"
#       },
#       {
#         "display_name": "Agronomy",
#         "id": "https://openalex.org/C6557445",
#         "level": 1,
#         "score": 0.0,
#         "wikidata": "https://www.wikidata.org/wiki/Q173113"
#       },
#       {
#         "display_name": "Biology",
#         "id": "https://openalex.org/C86803240",
#         "level": 0,
#         "score": 0.0,
#         "wikidata": "https://www.wikidata.org/wiki/Q420"
#       }
#     ],
#     "corresponding_author_ids": [
#       "https://openalex.org/A2142907911"
#     ],
#     "corresponding_institution_ids": [
#       "https://openalex.org/I135310074"
#     ],
#     "counts_by_year": [
#       {
#         "cited_by_count": 1,
#         "year": 2023
#       },
#       {
#         "cited_by_count": 2,
#         "year": 2020
#       },
#       {
#         "cited_by_count": 2,
#         "year": 2018
#       },
#       {
#         "cited_by_count": 2,
#         "year": 2016
#       },
#       {
#         "cited_by_count": 4,
#         "year": 2015
#       },
#       {
#         "cited_by_count": 3,
#         "year": 2014
#       },
#       {
#         "cited_by_count": 5,
#         "year": 2013
#       },
#       {
#         "cited_by_count": 5,
#         "year": 2012
#       }
#     ],
#     "created_date": "2016-06-24",
#     "display_name": "Automatic Decentralized Clustering for Wireless Sensor Networks",
#     "doi": "https://doi.org/10.1155/wcn.2005.686",
#     "grants": [],
#     "id": "https://openalex.org/W2124578313",
#     "ids": {
#       "doi": "https://doi.org/10.1155/wcn.2005.686",
#       "mag": "2124578313",
#       "openalex": "https://openalex.org/W2124578313"
#     },
#     "is_paratext": false,
#     "is_retracted": false,
#     "language": "en",
#     "locations": [
#       {
#         "is_oa": true,
#         "landing_page_url": "https://doi.org/10.1155/wcn.2005.686",
#         "license": "cc-by",
#         "pdf_url": null,
#         "source": {
#           "display_name": "Eurasip Journal on Wireless Communications and Networking",
#           "host_organization": "https://openalex.org/P4310319965",
#           "host_organization_lineage": [
#             "https://openalex.org/P4310319965"
#           ],
#           "host_organization_lineage_names": [
#             "Springer Nature"
#           ],
#           "host_organization_name": "Springer Nature",
#           "id": "https://openalex.org/S82675988",
#           "is_in_doaj": true,
#           "is_oa": true,
#           "issn": [
#             "1687-1499",
#             "1687-1472"
#           ],
#           "issn_l": "1687-1472",
#           "type": "journal"
#         },
#         "version": "publishedVersion"
#       }
#     ],
#     "locations_count": 1,
#     "mesh": [],
#     "ngrams_url": "https://api.openalex.org/works/W2124578313/ngrams",
#     "open_access": {
#       "any_repository_has_fulltext": false,
#       "is_oa": true,
#       "oa_status": "gold",
#       "oa_url": "https://doi.org/10.1155/wcn.2005.686"
#     },
#     "primary_location": {
#       "is_oa": true,
#       "landing_page_url": "https://doi.org/10.1155/wcn.2005.686",
#       "license": "cc-by",
#       "pdf_url": null,
#       "source": {
#         "display_name": "Eurasip Journal on Wireless Communications and Networking",
#         "host_organization": "https://openalex.org/P4310319965",
#         "host_organization_lineage": [
#           "https://openalex.org/P4310319965"
#         ],
#         "host_organization_lineage_names": [
#           "Springer Nature"
#         ],
#         "host_organization_name": "Springer Nature",
#         "id": "https://openalex.org/S82675988",
#         "is_in_doaj": true,
#         "is_oa": true,
#         "issn": [
#           "1687-1499",
#           "1687-1472"
#         ],
#         "issn_l": "1687-1472",
#         "type": "journal"
#       },
#       "version": "publishedVersion"
#     },
#     "publication_date": "2005-12-01",
#     "publication_year": 2005,
#     "referenced_works": [
#       "https://openalex.org/W7309667",
#       "https://openalex.org/W1525394761",
#       "https://openalex.org/W1787734157",
#       "https://openalex.org/W2012987308",
#       "https://openalex.org/W2035918100",
#       "https://openalex.org/W2047496769",
#       "https://openalex.org/W2056099894",
#       "https://openalex.org/W2074567338",
#       "https://openalex.org/W2086976228",
#       "https://openalex.org/W2087983778",
#       "https://openalex.org/W2098502330",
#       "https://openalex.org/W2099751474",
#       "https://openalex.org/W2101678493",
#       "https://openalex.org/W2104846640",
#       "https://openalex.org/W2105081458",
#       "https://openalex.org/W2106335692",
#       "https://openalex.org/W2113829484",
#       "https://openalex.org/W2147547332",
#       "https://openalex.org/W2163533836",
#       "https://openalex.org/W2167465093",
#       "https://openalex.org/W2317392131"
#     ],
#     "referenced_works_count": 21,
#     "related_works": [
#       "https://openalex.org/W2110009678",
#       "https://openalex.org/W2139009501",
#       "https://openalex.org/W2171315892",
#       "https://openalex.org/W2375792623",
#       "https://openalex.org/W2393474744",
#       "https://openalex.org/W2416421747",
#       "https://openalex.org/W2795033032",
#       "https://openalex.org/W3206922092",
#       "https://openalex.org/W4230159204",
#       "https://openalex.org/W4236024500"
#     ],
#     "relevance_score": 1041.896,
#     "title": "Automatic Decentralized Clustering for Wireless Sensor Networks",
#     "type": "journal-article",
#     "updated_date": "2023-06-25T14:08:21.603554"
#   },
#   {
#     "abstract_inverted_index": null,
#     "apc_list": null,
#     "apc_paid": null,
#     "authorships": [
#       {
#         "author": {
#           "display_name": "Wen Chih-Yu",
#           "id": "https://openalex.org/A4316051676",
#           "orcid": null
#         },
#         "author_position": "first",
#         "institutions": [],
#         "is_corresponding": false,
#         "raw_affiliation_string": "",
#         "raw_affiliation_strings": []
#       },
#       {
#         "author": {
#           "display_name": "Sethares William A",
#           "id": "https://openalex.org/A4316051677",
#           "orcid": null
#         },
#         "author_position": "last",
#         "institutions": [],
#         "is_corresponding": false,
#         "raw_affiliation_string": "",
#         "raw_affiliation_strings": []
#       }
#     ],
#     "best_oa_location": null,
#     "biblio": {
#       "first_page": null,
#       "issue": null,
#       "last_page": null,
#       "volume": null
#     },
#     "cited_by_api_url": "https://api.openalex.org/works?filter=cites:W4313426343",
#     "cited_by_count": 0,
#     "concepts": [
#       {
#         "display_name": "Wireless sensor network",
#         "id": "https://openalex.org/C24590314",
#         "level": 2,
#         "score": 0.63524914,
#         "wikidata": "https://www.wikidata.org/wiki/Q336038"
#       },
#       {
#         "display_name": "Cluster analysis",
#         "id": "https://openalex.org/C73555534",
#         "level": 2,
#         "score": 0.6258842,
#         "wikidata": "https://www.wikidata.org/wiki/Q622825"
#       },
#       {
#         "display_name": "Computer science",
#         "id": "https://openalex.org/C41008148",
#         "level": 0,
#         "score": 0.5762639,
#         "wikidata": "https://www.wikidata.org/wiki/Q21198"
#       },
#       {
#         "display_name": "Wireless",
#         "id": "https://openalex.org/C555944384",
#         "level": 2,
#         "score": 0.4181165,
#         "wikidata": "https://www.wikidata.org/wiki/Q249"
#       },
#       {
#         "display_name": "Distributed computing",
#         "id": "https://openalex.org/C120314980",
#         "level": 1,
#         "score": 0.40253592,
#         "wikidata": "https://www.wikidata.org/wiki/Q180634"
#       },
#       {
#         "display_name": "Computer network",
#         "id": "https://openalex.org/C31258907",
#         "level": 1,
#         "score": 0.38322827,
#         "wikidata": "https://www.wikidata.org/wiki/Q1301371"
#       },
#       {
#         "display_name": "Telecommunications",
#         "id": "https://openalex.org/C76155785",
#         "level": 1,
#         "score": 0.1900954,
#         "wikidata": "https://www.wikidata.org/wiki/Q418"
#       },
#       {
#         "display_name": "Artificial intelligence",
#         "id": "https://openalex.org/C154945302",
#         "level": 1,
#         "score": 0.18953311,
#         "wikidata": "https://www.wikidata.org/wiki/Q11660"
#       }
#     ],
#     "corresponding_author_ids": [],
#     "corresponding_institution_ids": [],
#     "counts_by_year": [],
#     "created_date": "2023-01-06",
#     "display_name": "Automatic Decentralized Clustering for Wireless Sensor Networks",
#     "doi": null,
#     "grants": [],
#     "id": "https://openalex.org/W4313426343",
#     "ids": {
#       "openalex": "https://openalex.org/W4313426343"
#     },
#     "is_paratext": false,
#     "is_retracted": false,
#     "language": "en",
#     "locations": [
#       {
#         "is_oa": false,
#         "landing_page_url": "https://doaj.org/article/d15a27e30f0a4e41af57426bb2b9fe87",
#         "license": null,
#         "pdf_url": null,
#         "source": {
#           "display_name": "DOAJ (DOAJ: Directory of Open Access Journals)",
#           "host_organization": null,
#           "host_organization_lineage": [],
#           "host_organization_lineage_names": [],
#           "host_organization_name": null,
#           "id": "https://openalex.org/S4306401280",
#           "is_in_doaj": false,
#           "is_oa": true,
#           "issn": null,
#           "issn_l": null,
#           "type": "repository"
#         },
#         "version": null
#       }
#     ],
#     "locations_count": 1,
#     "mesh": [],
#     "ngrams_url": "https://api.openalex.org/works/W4313426343/ngrams",
#     "open_access": {
#       "any_repository_has_fulltext": false,
#       "is_oa": false,
#       "oa_status": "closed",
#       "oa_url": null
#     },
#     "primary_location": {
#       "is_oa": false,
#       "landing_page_url": "https://doaj.org/article/d15a27e30f0a4e41af57426bb2b9fe87",
#       "license": null,
#       "pdf_url": null,
#       "source": {
#         "display_name": "DOAJ (DOAJ: Directory of Open Access Journals)",
#         "host_organization": null,
#         "host_organization_lineage": [],
#         "host_organization_lineage_names": [],
#         "host_organization_name": null,
#         "id": "https://openalex.org/S4306401280",
#         "is_in_doaj": false,
#         "is_oa": true,
#         "issn": null,
#         "issn_l": null,
#         "type": "repository"
#       },
#       "version": null
#     },
#     "publication_date": "2005-01-01",
#     "publication_year": 2005,
#     "referenced_works": [],
#     "referenced_works_count": 0,
#     "related_works": [
#       "https://openalex.org/W763609066",
#       "https://openalex.org/W1537044748",
#       "https://openalex.org/W1587227328",
#       "https://openalex.org/W1999627569",
#       "https://openalex.org/W2002555544",
#       "https://openalex.org/W2091675555",
#       "https://openalex.org/W2130966263",
#       "https://openalex.org/W2510217115",
#       "https://openalex.org/W2998813341",
#       "https://openalex.org/W3119417306"
#     ],
#     "title": "Automatic Decentralized Clustering for Wireless Sensor Networks",
#     "type": "journal-article",
#     "updated_date": "2023-05-26T06:41:36.009908"
#   }
# ]

# %%
from tqdm import tqdm

skip_count = 0
missed_count = 0
for index, row in tqdm(meta_infos.iterrows(), total=len(meta_infos)):
    doi = row["doi"]
    title = row["title"]

    # If doi is not a string, skip
    if not isinstance(title, str) or len(title) == 0:
        skip_count += 1
        # print(f"Skipping {index}: {title} ({doi})")
        continue

    if openalex_exists(title):
        continue

    # print(f"Processing {index}: {title}")

    cleaned_title = title.replace(",", "")
    cleaned_title = cleaned_title.replace("&", " ")
    cleaned_title = cleaned_title.replace("\"", "")

    try:
        data = Works().search_filter(title=cleaned_title).get()
    except Exception as e:
        data = None
        print(f"Error with title: {title}")

    if data is not None and len(data) > 0:
        store_openalex_data(title, data)
    else:
        missed_count += 1
        # print(f"Could not find {index}: {title} ({doi})")

print(f"Skipped {skip_count} entries due to missing title.")
print(f"Could not find {missed_count} entries.")
# Out:
#  95%|█████████▍| 25433/26843 [30:01<10:49:02, 27.62s/it]
# Error with title: ProFlow: Learning to Predict Optical Flow
# 100%|██████████| 26843/26843 [41:03<00:00, 10.90it/s]
# Skipped 8 entries due to missing title.
# Could not find 1872 entries.

# %%
db.close()
