# %% [markdown]
# # ORKG Data preparation
#
# This notebook prepares a dataframe from the ORKG data.

# %%
import sqlite3

# Open a connection to the SQLite database file
db = sqlite3.connect("data/datalake.db")

# Create a cursor object to execute SQL statements
cursor = db.cursor()
cursor.execute("CREATE TABLE IF NOT EXISTS orkg_subjects (id TEXT PRIMARY KEY, data JSON)")

# %% [markdown]
# # Label Mapping
#
# The ORKG data is inconsistent in the naming of labels.
#
# ```json
# {
#   "author": "P27",
#   "doi": "P26",
#   "publication month": "P28",
#   "publication year": "P29",
#   "publisher": "HAS_VENUE",
#   "title": "rdf-schema#label",
#   "url": "url"
# }
# ```

# %%
import json
from src.utils.utils_json import write_json, print_json

data = []

for id, raw in cursor.execute("SELECT * FROM orkg_statements"):
    statements = json.loads(raw)["statements"]

    title = statements[0]["subject"]["label"]

    labels = {}
    for statement in statements:
        label_name = statement['predicate']['label']

        if label_name not in labels:
            labels[label_name] = []

        label = statement['object']['label']
        labels[label_name].append(label)

    # Remove duplicates and trim whitespace
    for label_name in labels:
        labels[label_name] = [label.strip() for label in labels[label_name]]
        labels[label_name] = list(set(labels[label_name]))
        # Remove empty labels
        labels[label_name] = [label for label in labels[label_name] if label]

    # Remove empty labels
    labels = {k: v for k, v in labels.items() if len(v) > 0}

    data.append({
        "id": id,
        "title": title,
        "labels": labels,
    })

# %%
write_json("data/orkg.json", data)

# %%
print_json(data[:5])
# Out:
# [
#   {
#     "id": "R209491",
#     "labels": {
#       "author": [
#         "R. Scherer",
#         "R. Windisch",
#         "M. Kadolsky"
#       ],
#       "contribution": [
#         "Contribution 1"
#       ],
#       "description": [
#         "Covers systems organization and hardware architecture. Roughly includes material in ACM Subject Classes C.0, C.1, and C.5."
#       ],
#       "doi": [
#         "10.1109/EESMS.2015.7175848"
#       ],
#       "has subfield": [
#         "Digital Communications and Networking",
#         "Data Storage Systems",
#         "Computer and Systems Architecture",
#         "Hardware Systems",
#         "Digital Circuits",
#         "Robotics"
#       ],
#       "publication year": [
#         "2015"
#       ],
#       "research field": [
#         "Computer Engineering"
#       ],
#       "same as": [
#         "Arxiv ID: cs.RO",
#         "Arxiv ID: cs.AR"
#       ],
#       "url": [
#         "https://ieeexplore.ieee.org/abstract/document/7175848"
#       ],
#       "venue": [
#         "2015 IEEE Workshop on Environmental, Energy, and Structural Monitoring Systems (EESMS) Proceedings"
#       ]
#     },
#     "title": "Knowledge management framework for monitoring systems improving building energy efficiency"
#   },
#   {
#     "id": "R585639",
#     "labels": {
#       "Attributes": [
#         "Publicly and commercially available",
#         "Available as server, web and desktop-application",
#         "Flexible and interactive graphs"
#       ],
#       "Has Relations": [
#         "present_at and reachable"
#       ],
#       "Has method ": [
#         "Modal First-Order Logic"
#       ],
#       "Input format": [
#         ".xlsx",
#         ".txt",
#         ".csv"
#       ],
#       "Year of study": [
#         "2014"
#       ],
#       "author": [
#         "Usip, P. U",
#         "Akinkunmi, B. O."
#       ],
#       "contribution": [
#         "Contribution 1"
#       ],
#       "has Proof": [
#         "Tableau"
#       ],
#       "has domain": [
#         "Spatiotemporal"
#       ],
#       "has implementation": [
#         "alibi reasoning and distribution"
#       ],
#       "has research problem": [
#         "Reasoning with Spatial knowledge"
#       ],
#       "publication year": [
#         "2020"
#       ],
#       "research field": [
#         "Theoretical Computer Science"
#       ],
#       "result key-insight": [
#         "A Semi-decidable qualitative logic"
#       ],
#       "same as": [
#         "http://uri.gbv.de/terminology/dfg/409-01"
#       ],
#       "use case": [
#         "Commercial BI"
#       ],
#       "venue": [
#         "Benin Journal of Applied Computer Science"
#       ]
#     },
#     "title": "Contribution 1"
#   },
#   {
#     "id": "R504922",
#     "labels": {
#       "Benchmark": [
#         "Benchmark Exact Street2Shop",
#         "Benchmark DeepFashion - Consumer-to-shop"
#       ],
#       "author": [
#         "Anna Wroblewska",
#         "Andrzej Michalowski",
#         "Mikolaj Wieczorek",
#         "Jacek Dabrowski"
#       ],
#       "contribution": [
#         "Contribution \tRST Model (ResNet50-IBN-A, 320x320)"
#       ],
#       "dataset": [
#         "Deepfashion - consumer-to-shop",
#         "Exact street2shop"
#       ],
#       "description": [
#         "Theory and methods for processing signals representing audio, speech, and language, and their applications. This includes analysis, synthesis, enhancement, transformation, classification and interpretation of such signals as well as the design, development, and evaluation of associated signal processing systems. Machine learning and pattern analysis applied to any of the above areas is also welcome. Specific topics of interest include: auditory modeling and hearing aids; acoustic beamforming and source localization; classification of acoustic scenes; speaker separation; active noise control and echo cancellation; enhancement; de-reverberation; bioacoustics; music signals analysis, synthesis and modification; music information retrieval; audio for multimedia and joint audio-video processing; spoken and written language modeling, segmentation, tagging, parsing, understanding, and translation; text mining; speech production, perception, and psychoacoustics; speech analysis, synthesis, and perceptual modeling and coding; robust speech recognition; speaker recognition and characterization; deep learning, online learning, and graphical models applied to speech, audio, and language signals; and implementation aspects ranging from system architecture to fast algorithms.",
#         "Covers all aspects of computer communication networks, including network architecture and design, network protocols, and internetwork standards (like TCP/IP). Also includes topics, such as web caching, that are directly relevant to Internet architecture and performance.",
#         "Theory, algorithms, and architectures for the formation, capture, processing, communication, analysis, and display of images, video, and multidimensional signals in a wide variety of applications. Topics of interest include: mathematical, statistical, and perceptual image and video modeling and representation; linear and nonlinear filtering, de-blurring, enhancement, restoration, and reconstruction from degraded, low-resolution or tomographic data; lossless and lossy compression and coding; segmentation, alignment, and recognition; image rendering, visualization, and printing; computational imaging, including ultrasound, tomographic and magnetic resonance imaging; and image and video analysis, synthesis, storage, search and retrieval.",
#         "Covers design tools, software metrics, testing and debugging, programming environments, etc",
#         "Covers all aspects of logic in computer science, including finite model theory, logics of programs, modal logic, and program verification.",
#         "Covers human factors, user interfaces, and collaborative computing.",
#         "Covers all aspects of computer graphics",
#         "Covers models of computation, complexity classes, structural complexity, complexity tradeoffs, upper and lower bounds. Roughly includes material in ACM Subject Classes F.1 (computation by abstract devices), F.2.3 (tradeoffs among complexity measures), and F.4.3 (formal languages), although some material in formal languages may be more appropriate for Logic in Computer Science. Some material in F.2.1 and F.2.2, may also be appropriate here, but is more likely to have Data Structures and Algorithms as the primary subject area.",
#         "Papers on all aspects of machine learning research (supervised, unsupervised, reinforcement learning, bandit problems, and so on) including also robustness, explanation, fairness, and methodology.",
#         "Covers theoretical and experimental aspects of information theory and coding.",
#         "Covers multiagent systems, distributed artificial intelligence, intelligent agents, coordinated interactions.",
#         "Roughly includes material in ACM Subject Classes I.3.5 and F.2.2.\n[Wiki] Computational geometry is a branch of computer science devoted to the study of algorithms which can be stated in terms of geometry.",
#         "Covers all theoretical and applied aspects at the intersection of computer science and game theory, including work in mechanism design, learning in games (which may overlap with Learning), foundations of agent modeling in games (which may overlap with Multiagent systems), coordination, specification and formal methods for non-cooperative computational environments. The area also deals with applications of game theory to areas such as electronic commerce.",
#         "Educational Technology with Artificial Intelligence features",
#         "Covers programming language semantics, language features, programming approaches (such as object-oriented programming, functional programming, logic programming). Also includes material on compilers oriented towards programming languages"
#       ],
#       "evaluation": [
#         "Quantity mAP_43.0",
#         "Quantity Rank-20_73.6",
#         "Quantity mAP_46.8",
#         "Quantity Rank-20_77.2",
#         "Quantity Rank-10_69.8",
#         "Quantity Rank-50_84.1",
#         "Quantity Rank-10_71.1",
#         "Quantity Rank-1_53.7",
#         "Quantity Rank-1_37.8"
#       ],
#       "has subfield": [
#         "Software Engineering and Programming Languages",
#         "Digital Libraries",
#         "Massively Parallel and Data-Intensive Systems",
#         "Requirements Engineering",
#         "Computers and Society",
#         "Graphics",
#         "Human Computer Interfaces",
#         "Computational Complexity",
#         "Natural Language Processing",
#         "Operating, Communication, Database and Distributed Systems",
#         "Semantic Web",
#         "Numerical Analysis/Scientific Computing",
#         "Programming Languages/Compilers",
#         "Information Systems, Process and Knowledge Management",
#         "OS/Networks",
#         "Learner-Interface Interaction",
#         "Interactive and Intelligent Systems, Image and Language Processing, Computer Graphics and Visualisation",
#         "Networking and Internet Architecture",
#         "Neural and Evolutionary Computing",
#         "Computer and Systems Architecture",
#         "Artificial Intelligence",
#         "Machine Learning",
#         "Software Engineering",
#         "Computer Science and Game Theory",
#         "Computer Architecture and Embedded Systems",
#         "Computational Geometry",
#         "Security and Dependability",
#         "Image and Video Processing",
#         "Logic in Computer Science",
#         "Multiagent Systems",
#         "Databases/Information Systems",
#         "Theory/Algorithms",
#         "Operating Systems",
#         "Computer Science General Literature",
#         "Cryptography and Security",
#         "Computer Vision and Pattern Recognition",
#         "Information Theory",
#         "Theoretical Computer Science",
#         "Audio and Speech Processing"
#       ],
#       "has synonym": [
#         "Human-Computer Interaction",
#         "Machine Learning",
#         "Computer Science"
#       ],
#       "hasQuantityKind": [
#         "Map",
#         "Rank-10",
#         "Rank-20",
#         "Rank-50",
#         "Rank-1"
#       ],
#       "model": [
#         "Rst model resnet50-ibn-a 320x320"
#       ],
#       "numericValue": [
#         "46.8",
#         "53.7",
#         "69.8",
#         "77.2",
#         "37.8",
#         "73.6",
#         "84.1",
#         "43.0",
#         "71.1"
#       ],
#       "publication month": [
#         "3"
#       ],
#       "publication year": [
#         "2020"
#       ],
#       "quantityValue": [
#         "quantityValue"
#       ],
#       "research field": [
#         "Computer Sciences"
#       ],
#       "research problem": [
#         "Image retrieval"
#       ],
#       "same as": [
#         "Arxiv ID: cs.OS",
#         "Arxiv ID: cs.CG",
#         "Arxiv ID: cs.DL",
#         "http://uri.gbv.de/terminology/dfg/409",
#         "Arxiv ID: cs.NI",
#         "Arxiv ID: cs.HC",
#         "Arxiv ID: cs.LG",
#         "Arxiv ID: cs.SE",
#         "Arxiv ID: cs.CY",
#         "https://en.wikipedia.org/wiki/Natural_language_processing",
#         "Arxiv ID: eess.AS",
#         "Arxiv ID: cs.MA",
#         "http://uri.gbv.de/terminology/dfg/409-06",
#         "Arxiv ID: cs.CC",
#         "http://uri.gbv.de/terminology/dfg/409-08",
#         "http://uri.gbv.de/terminology/dfg/409-01",
#         "http://uri.gbv.de/terminology/dfg/409-04",
#         "http://uri.gbv.de/terminology/dfg/409-03",
#         "Arxiv ID: cs.NE",
#         "http://uri.gbv.de/terminology/dfg/409-02",
#         "Arxiv ID: cs.GT",
#         "Arxiv ID: cs.DB",
#         "https://en.wikipedia.org/wiki/Semantic_Web",
#         "Arxiv ID: cs.CV",
#         "Arxiv ID: cs.CR",
#         "http://uri.gbv.de/terminology/dfg/409-07",
#         "Arxiv ID: cs.AI",
#         "Arxiv ID: stat.ML",
#         "Arxiv ID: math.IT",
#         "Arxiv ID: cs.GL",
#         "Arxiv ID: cs.PL",
#         "http://uri.gbv.de/terminology/dfg/409-05",
#         "Arxiv ID: eess.IV",
#         "Arxiv ID: cs.IT",
#         "Arxiv ID: cs.LO",
#         "Arxiv ID: cs.GR"
#       ],
#       "source code": [
#         "https://github.com/mikwieczorek/centroids-reid"
#       ],
#       "url": [
#         "https://arxiv.org/abs/2003.04094v1.pdf"
#       ]
#     },
#     "title": "A Strong Baseline for Fashion Retrieval with Person Re-Identification Models"
#   },
#   {
#     "id": "R146959",
#     "labels": {
#       "Experimental validation of mathematical model": [
#         "Uses sheep data"
#       ],
#       "Has ORCID": [
#         "0000-0002-5582-3907",
#         "0000-0001-5429-2836"
#       ],
#       "Mathematical model": [
#         "Model of blood volume response to infusion and hemorrhage"
#       ],
#       "Mathematical model used In-silico study": [
#         "Arthur Guyton's model of human cardiovascular physiology"
#       ],
#       "author": [
#         "Jin-Oh Hahn",
#         "Xin Jin",
#         "Ramin Bighamian"
#       ],
#       "contribution": [
#         "Contribution 1"
#       ],
#       "doi": [
#         "10.1109/tbme.2018.2880927"
#       ],
#       "publication month": [
#         "7"
#       ],
#       "publication year": [
#         "2019"
#       ],
#       "research field": [
#         "Control Theory"
#       ],
#       "research problem": [
#         "In-silico evaluation of closed-loop controllers",
#         "Adaptive control of fluid resuscitation",
#         "modeling blood volume response to infusion and hemorrhage",
#         "automatic resusictation therapy"
#       ],
#       "url": [
#         "https://ieeexplore.ieee.org/document/8540454"
#       ],
#       "venue": [
#         "IEEE Transactions on Biomedical Engineering"
#       ]
#     },
#     "title": "Contribution 1"
#   },
#   {
#     "id": "R191366",
#     "labels": {
#       "Accuracy": [
#         "86.4",
#         "87.8"
#       ],
#       "F1-score": [
#         "87.0",
#         "88.05"
#       ],
#       "Fake News": [
#         "120",
#         "91"
#       ],
#       "Has Datasets": [
#         "PolitiFact",
#         "BuzzFeed"
#       ],
#       "Precision": [
#         "86.7",
#         "84.9"
#       ],
#       "Real News": [
#         "120",
#         "91"
#       ],
#       "Recall": [
#         "89.3"
#       ],
#       "author": [
#         "Suhang Wang",
#         "Huan Liu",
#         "Kai Shu"
#       ],
#       "contribution": [
#         "Contribution 1"
#       ],
#       "description": [
#         "Proposed a tri-relationship fake news (TrFN) algorithm to identify the fake news news by exploiting  news, publisher, user and social context. Furthermore, they investigate correlation between publisher-news and user-news respectively."
#       ],
#       "doi": [
#         "10.1145/3289600.3290994"
#       ],
#       "method": [
#         "Semi Supervised learning with tri-relationship (TRIFN) model"
#       ],
#       "publication month": [
#         "1"
#       ],
#       "publication year": [
#         "2019"
#       ],
#       "research field": [
#         "Science and Technology Studies"
#       ],
#       "research problem": [
#         "Misinformation & Fake News"
#       ],
#       "result": [
#         "PolitiFact",
#         "BuzzFeed"
#       ],
#       "venue": [
#         "Proceedings of the Twelfth ACM International Conference on Web Search and Data Mining"
#       ]
#     },
#     "title": "Contribution 1"
#   }
# ]

# %%
df_input = {
    "id": [],
    "title": [],
    "doi": [],
    "research field": [],
    "subfields": [],
}

for row in data:
    df_input["id"].append(row["id"])
    df_input["title"].append(row["title"])
    df_input["doi"].append(row["labels"].get("doi", []))
    df_input["subfields"].append(row["labels"].get("has subfield", []))

    rf = row["labels"].get("research field")
    if rf:
        df_input["research field"].append(rf[0])
    else:
        df_input["research field"].append("")

# %%
import pandas as pd

df = pd.DataFrame(df_input)
df.to_csv("data/orkg.csv", index=False)
df
# Out:
#             id                                              title  \
# 0      R209491  Knowledge management framework for monitoring ...
# 1      R585639                                     Contribution 1
# 2      R504922  A Strong Baseline for Fashion Retrieval with P...
# 3      R146959                                     Contribution 1
# 4      R191366                                     Contribution 1
# ...        ...                                                ...
# 26740   R44879                                           Virology
# 26741  R521270  Comprehensive Attention Self-Distillation for ...
# 26742  R554286  How Do Graph Networks Generalize to Large and ...
# 26743  R532777  Improving the Gating Mechanism of Recurrent Ne...
# 26744   R57618                                 Population Biology
#
#                                 doi                    research field  \
# 0      [10.1109/EESMS.2015.7175848]              Computer Engineering
# 1                                []      Theoretical Computer Science
# 2                                []                 Computer Sciences
# 3       [10.1109/tbme.2018.2880927]                    Control Theory
# 4         [10.1145/3289600.3290994]    Science and Technology Studies
# ...                             ...                               ...
# 26740  [10.1016/j.ijid.2020.02.033]                          Virology
# 26741                            []                 Computer Sciences
# 26742                            []                 Computer Sciences
# 26743                            []                 Computer Sciences
# 26744                            []  Ecology and Evolutionary Biology
#
#                                                subfields
# 0      [Digital Communications and Networking, Data S...
# 1                                                     []
# 2      [Software Engineering and Programming Language...
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 26740                                                 []
# 26741  [Software Engineering and Programming Language...
# 26742  [Software Engineering and Programming Language...
# 26743  [Software Engineering and Programming Language...
# 26744  [Botany, Evolution, Population Biology, Terres...
#
# [26745 rows x 5 columns]

# %%
subfields = set()

for inx, row in df.iterrows():
    if row["subfields"]:
        subfields.update(row["subfields"])

subfields = list(subfields)
subfields.sort()

print("Subfields:", len(subfields))
print_json(subfields)
# Out:
# Subfields: 692
# [
#   "Accelerator Physics",
#   "Acoustics, Dynamics, and Controls",
#   "Adaptation and Self-Organizing Systems",
#   "Aerodynamics and Fluid Mechanics",
#   "Aeronautical Vehicles",
#   "Aerospace Engineering",
#   "African",
#   "African Languages and Societies",
#   "African Studies",
#   "Agricultural Economics, Agricultural Policy, Agricultural Sociology",
#   "Agricultural and Resource Economics",
#   "Agriculture, Forestry and Veterinary Medicine",
#   "Agronomy and Crop Sciences",
#   "Algebra",
#   "Algebraic Geometry",
#   "Algebraic Topology",
#   "American Art and Architecture",
#   "American Film Studies",
#   "American Literature",
#   "American Material Culture",
#   "American Politics",
#   "American Popular Culture",
#   "American Studies",
#   "Anaesthesiology",
#   "Analysis",
#   "Analytical Chemistry",
#   "Anatomy",
#   "Ancient History (Greek and Roman through Late Antiquity)",
#   "Ancient Philosophy",
#   "Ancient, Medieval, Renaissance and Baroque Art and Architecture",
#   "Animal Breeding, Animal Nutrition, Animal Husbandry",
#   "Animal Physiology and Biochemistry",
#   "Animal Sciences",
#   "Anthropological Linguistics/Sociolinguistics",
#   "Applied Linguistics",
#   "Applied Mathematics",
#   "Applied Mechanics",
#   "Applied Mechanics, Statics and Dynamics",
#   "Applied Physics",
#   "Applied Statistics",
#   "Aquaculture and Fisheries",
#   "Archaeological",
#   "Architecture, Building and Construction History, Construction Research, Sustainable Building Technology",
#   "Art History",
#   "Artificial Intelligence",
#   "Arts and Humanities",
#   "Asian",
#   "Asian Art and Architecture",
#   "Asian Studies",
#   "Astrodynamics",
#   "Astrophysics and Astronomy",
#   "Atmospheric Sciences",
#   "Atomic Physics",
#   "Atomic and Molecular Clusters",
#   "Atomic, Molecular and Optical Physics",
#   "Audio and Speech Processing",
#   "Automation, Control Systems, Robotics, Mechatronics, Cyber Physical Systems",
#   "Bacteriology",
#   "Behavior and Ethology",
#   "Behavioral Economics",
#   "Behavioral Neurobiology",
#   "Biblical Studies",
#   "Biochemical and Biomolecular Engineering",
#   "Biochemistry",
#   "Biochemistry, Biophysics, and Structural Biology",
#   "Bioelectrical and neuroengineering",
#   "Biogeochemistry",
#   "Biogerontology and Geriatric Medicine",
#   "Bioimaging and biomedical optics",
#   "Bioinformatics",
#   "Biological Chemistry and Food Chemistry",
#   "Biological Engineering",
#   "Biological Process Engineering",
#   "Biological Psychiatry",
#   "Biological Psychology",
#   "Biological and Biomimetic Chemistry",
#   "Biological and Chemical Physics",
#   "Biological and Physical",
#   "Biology and Biomimetic Materials",
#   "Biology/Integrated Biology/ Integrated Biomedical Sciences",
#   "Biomaterials",
#   "Biomechanical Engineering",
#   "Biomechanics",
#   "Biomechanics and biotransport",
#   "Biomedical",
#   "Biomedical Engineering and Bioengineering",
#   "Biomedical Systems Technology",
#   "Biomedical devices and instrumentation",
#   "Biometry",
#   "Biomolecules",
#   "Biophysics",
#   "Biostatistics",
#   "Biotechnology",
#   "Botany",
#   "Broadcast/Video Studies",
#   "Business Administration",
#   "Byzantine and Modern Greek",
#   "Cancer Biology",
#   "Cardiac and Vascular Sugery",
#   "Cardiology, Angiology",
#   "Catalysis and Reaction Engineering",
#   "Category Theory",
#   "Cell Behavior",
#   "Cell Biology",
#   "Cell and Developmental Biology",
#   "Cellular Automata and Lattice Gases",
#   "Cellular and Molecular Physiology",
#   "Ceramic Materials",
#   "Chaotic Dynamics",
#   "Chemical Engineering",
#   "Chemical Solid State and Surface Research",
#   "Chemical and Thermal Process Engineering",
#   "Chemistry",
#   "Civil Engineering",
#   "Civil and Environmental Engineering",
#   "Classical Archaeology and Art History",
#   "Classical Literature and Philology",
#   "Classical Physics",
#   "Classics",
#   "Climate",
#   "Clinical Immunology and Allergology",
#   "Clinical Infectiology and Tropical Medicine",
#   "Clinical Neurology; Neurosurgery and Neuroradiology",
#   "Clinical Psychiatry, Psychotherapy, Child and Adolescent Psychiatry",
#   "Coating and Surface Technology",
#   "Cognition and Perception",
#   "Cognitive Neuroscience",
#   "Cognitive Psychology",
#   "Communication Neuroscience",
#   "Communication Sciences",
#   "Communication Technology and New Media",
#   "Communications, High-Frequency and Network Technology, Theoretical Electrical Engineering",
#   "Community Psychology",
#   "Commutative Algebra",
#   "Comparative Literature",
#   "Comparative Methodologies and Theories",
#   "Comparative Nutrition",
#   "Comparative Politics",
#   "Comparative and Evolutionary Physiology",
#   "Comparative and Historical Linguistics",
#   "Complex Fluids",
#   "Complex Variables",
#   "Composition",
#   "Computational Biology",
#   "Computational Complexity",
#   "Computational Engineering",
#   "Computational Geometry",
#   "Computational Linguistics",
#   "Computational Neuroscience",
#   "Computational Physics",
#   "Computer Architecture and Embedded Systems",
#   "Computer Engineering",
#   "Computer Science General Literature",
#   "Computer Science and Game Theory",
#   "Computer Sciences",
#   "Computer Vision and Pattern Recognition",
#   "Computer and Systems Architecture",
#   "Computer-Aided Design of Materials and Simulation of Materials Behaviour from  Atomic to Microscopic Scale",
#   "Computer-Aided Engineering and Design",
#   "Computers and Society",
#   "Condensed Matter Physics",
#   "Construction Engineering/management",
#   "Construction Material Sciences, Chemistry, Building Physics",
#   "Contemporary Art",
#   "Continental Philosophy",
#   "Control Theory",
#   "Controls and Control Theory",
#   "Cosmochemistry",
#   "Cosmology",
#   "Cosmology, Relativity, and Gravity",
#   "Criminal Law",
#   "Criminology",
#   "Critical and Cultural Studies",
#   "Cryptography and Security",
#   "Cultural History",
#   "Dairy Science",
#   "Data Analysis, Statistics and Probability",
#   "Data Storage Systems",
#   "Databases/Information Systems",
#   "Demography, Population, and Ecology",
#   "Dentistry, Oral Surgery",
#   "Dermatology",
#   "Developmental Biology",
#   "Developmental Neurobiology",
#   "Developmental Neuroscience",
#   "Developmental Psychology",
#   "Developmental and Educational Psychology",
#   "Differential Geometry",
#   "Differential, Clinical and Medical Psychology, Methodology",
#   "Digital Circuits",
#   "Digital Communications and Networking",
#   "Digital Libraries",
#   "Diplomatic History",
#   "Discourse/Text Linguistics",
#   "Discrete Mathematics and Combinatorics",
#   "Disordered Systems and Neural Networks",
#   "Dramatic Literature, Criticism and Theory",
#   "Dynamic Systems",
#   "Dynamics/Dynamical Systems",
#   "Early Modern History",
#   "Earth Sciences",
#   "East Asian Languages and Societies",
#   "Ecology and Biodiversity of Animals and Ecosystems, Organismic Interactions",
#   "Ecology and Biodiversity of Plants and Ecosystems",
#   "Ecology and Evolutionary Biology",
#   "Ecology of Land Use",
#   "Econometrics",
#   "Economic History",
#   "Economic Policy, Applied Economics",
#   "Economic Theory",
#   "Economics",
#   "Education Systems and Educational Institutions",
#   "Educational Research",
#   "Educational Research on Socialization, Welfare and Professionalism Research",
#   "Ego-centric networks",
#   "Egyptology and Ancient Near Eastern Studies",
#   "Electrical Energy Generation, Distribution, Application",
#   "Electrical Engineering and Information Technology",
#   "Electrical and Computer Engineering",
#   "Electrical and Electronics",
#   "Electro-Mechanical Systems",
#   "Electromagnetics and photonics",
#   "Electronic Devices and Semiconductor Manufacturing",
#   "Electronic Semiconductors, Components, Circuits, Systems",
#   "Elementary Particles and Fields and String Theory",
#   "Empirical Social Research",
#   "Endocrinology",
#   "Energy Process Engineering",
#   "Energy Systems",
#   "Engineering",
#   "Engineering Design, Machine Elements, Product Development",
#   "Engineering Mechanics",
#   "Engineering Physics",
#   "Engineering Science and Materials (not elsewhere classified)",
#   "English Language and Literature",
#   "Entomology Food Science",
#   "Environmental Chemistry",
#   "Environmental Engineering",
#   "Environmental Health",
#   "Environmental Microbiology and Microbial Ecology",
#   "Environmental Sciences",
#   "Epidemiology",
#   "Epidemiology and Medical Biometry/Statistics",
#   "Epistemology",
#   "Ergonomics",
#   "Esthetics",
#   "Ethics",
#   "Ethics and Political Philosophy",
#   "Ethnic Studies",
#   "Ethnomusicology",
#   "European",
#   "European Languages and Societies (not elsewhere classified)",
#   "European Literature",
#   "Evolution",
#   "Evolution and Systematics of Plants and Fungi",
#   "Evolution, Anthropology",
#   "Exactly Solvable and Integrable Systems",
#   "Exercise Physiology",
#   "Experimental Condensed Matter Physics",
#   "Experimental Models for the Understanding of Nervous System Diseases",
#   "Experimental and Theoretical Network Neuroscience",
#   "Experimental and Theoretical Physics of Polymers",
#   "External Galaxies",
#   "Family, Life Course, and Society",
#   "Feminist Philosophy",
#   "Feminist, Gender and Sexuality Studies",
#   "Feminist, Gender, and Sexuality Studies",
#   "Film Studies",
#   "First/Second Language Acquisition",
#   "Fluid Dynamics",
#   "Fluid Mechanics",
#   "Fluid Mechanics, Technical Thermodynamics and Thermal Energy Engineering",
#   "Food Biotechnology",
#   "Food Chemistry",
#   "Food Microbiology",
#   "Food Processing",
#   "Forest Biology",
#   "Forest Management",
#   "Forestry and Forest Sciences",
#   "French Linguistics",
#   "French and Francophone Language and Literature",
#   "French and Francophone Literature",
#   "Fresh Water Studies",
#   "Gastroenterology",
#   "Gender",
#   "Gender and Sexuality",
#   "Gender, Race, Sexuality, and Ethnicity in Communication",
#   "General Education and History of Education",
#   "General Physics",
#   "General Topology",
#   "General and Domain-Specific Teaching and Learning",
#   "General and Visceral Surgery",
#   "General, Cognitive and Mathematical Psychology",
#   "Genetics",
#   "Genetics and Genomics",
#   "Genomics",
#   "Geochemistry",
#   "Geodesy, Photogrammetry, Remote Sensing, Geoinformatics, Cartography",
#   "Geographic Information Sciences",
#   "Geography",
#   "Geology",
#   "Geometry and Topology",
#   "Geophysics",
#   "Geophysics and Geodesy",
#   "Geophysics and Seismology",
#   "Geotechnical Engineering",
#   "Geotechnics, Hydraulic Engineering",
#   "German Language and Literature",
#   "German Linguistics",
#   "German Literature",
#   "Glaciology",
#   "Glass, Ceramics and Derived Composites",
#   "Graphics",
#   "Growth and Development",
#   "Gynaecology and Obstetrics",
#   "Hardware Systems",
#   "Harmonic Analysis and Representation",
#   "Health Communication",
#   "Health Psychology",
#   "Heat Transfer, Combustion",
#   "Hematology, Oncology",
#   "History",
#   "History and Philosophy of Physics",
#   "History of Art, Architecture and Archaeology",
#   "History of Philosophy",
#   "History of Religion",
#   "History of Religions of Eastern Origins",
#   "History of Religions of Western Origin",
#   "History of Science, Technology, and Medicine",
#   "Horticulture",
#   "Human Computer Interfaces",
#   "Human Factors, Ergonomics, Human-Machine Systems",
#   "Human Genetics",
#   "Human Geography",
#   "Human and Clinical Nutrition",
#   "Hydraulic and Turbo Engines and Piston Engines",
#   "Hydrogeology, Hydrology, Limnology, Urban Water Management, Water Chemistry, Integrated Water Resources Management",
#   "Image and Video Processing",
#   "Immunity",
#   "Immunology and Infectious Disease",
#   "Immunology of Infectious Disease",
#   "Immunopathology",
#   "Immunoprophylaxis and Therapy",
#   "Individual Linguistics",
#   "Indo-European Linguistics and Philology",
#   "Industrial Engineering",
#   "Industrial Organization",
#   "Industrial and Organizational Psychology",
#   "Inequality and Stratification",
#   "Information Science",
#   "Information Systems, Process and Knowledge Management",
#   "Information Theory",
#   "Inorganic Chemistry",
#   "Inorganic Molecular Chemistry - Synthesis and Characterisation",
#   "Instrumentation",
#   "Intellectual History",
#   "Interactive and Intelligent Systems, Image and Language Processing, Computer Graphics and Visualisation",
#   "International Economics",
#   "International Relations",
#   "International and Community Nutrition",
#   "International and Intercultural Communication",
#   "Interpersonal/Small Group Communication",
#   "Islamic Studies, Arabian Studies, Semitic Studies",
#   "Islamic World/Near East",
#   "Joining and Separation Technology",
#   "Journalism Studies",
#   "Jurisprudence",
#   "Labor Economics",
#   "Language Description/Documentation",
#   "Language, Societies, and Cultures",
#   "Latin American",
#   "Latin American Languages and Societies (not elsewhere classified",
#   "Latin American Literature",
#   "Learner-Interface Interaction",
#   "Legal",
#   "Life Sciences",
#   "Lightweight Construction, Textile Technology",
#   "Linguistic Anthrolpology",
#   "Linguistics",
#   "Literary Studies",
#   "Literature in English, Anglophone (other than British Isles and North America)",
#   "Literature in English, British Isles",
#   "Literature in English, North America (other than ethnic and minority)",
#   "Literature in English, North America, ethnic and minority",
#   "Logic and Foundations",
#   "Logic and foundations of mathematics",
#   "Logic in Computer Science",
#   "Machine Learning",
#   "Macroeconomics",
#   "Manufacturing",
#   "Mass Communication",
#   "Massively Parallel and Data-Intensive Systems",
#   "Materials Chemistry",
#   "Materials Engineering",
#   "Materials Science and Engineering",
#   "Materials in Sintering Processes and Generative Manufacturing Processes",
#   "Mathematical Software",
#   "Mathematics",
#   "Mathematics History and Overview",
#   "Measurement Systems",
#   "Mechanical Engineering",
#   "Mechanical Process Engineering",
#   "Mechanical Properties of Metallic Materials and their Microstructural Origins",
#   "Mechanics",
#   "Mechanics and Constructive Mechanical Engineering",
#   "Mechanics of Materials",
#   "Medical Informatics and Medical Bioinformatics",
#   "Medical Microbiology and Mycology, Hygiene, Molecular Infection Biology",
#   "Medical Physics",
#   "Medical Physics, Biomedical Technology",
#   "Medicinal Chemistry and Pharmaceutics",
#   "Medicinal-Pharmaceutical Chemistry",
#   "Medicine",
#   "Medicine and Health",
#   "Medieval German Literature",
#   "Medieval History",
#   "Membrane Science",
#   "Mesoscale and Nanoscale Physics",
#   "Metabolism, Biochemistry and Genetics of Microorganisms",
#   "Metal-Cutting and Abrasive Manufacturing Engineering",
#   "Metallurgical, Thermal and Thermomechanical Treatment of Materials",
#   "Metallurgy",
#   "Metaphysics",
#   "Meteorology",
#   "Methodologies : Quantitative, Qualitative, Comparative, and Historical",
#   "Metric Geometry",
#   "Microbial Ecology and Applied Microbiology",
#   "Microbial Physiology",
#   "Microbiology",
#   "Microsystems",
#   "Military History",
#   "Mineral Physics",
#   "Mineralogy, Petrology and Geochemistry",
#   "Models and Methods",
#   "Modern Art and Architecture",
#   "Modern German Literature",
#   "Modern and Current History",
#   "Molecular Biology",
#   "Molecular Chemistry",
#   "Molecular and Cellular Neurology and Neuropathology",
#   "Molecular and Cellular Neuroscience",
#   "Molecular genetics",
#   "Molecular, Genetic, and Biochemical Nutrition",
#   "Molecular, cellular, and tissue engineering",
#   "Morphology",
#   "Motor Control",
#   "Multi-Vehicle Systems and Air Traffic Control",
#   "Multiagent Systems",
#   "Music Theory",
#   "Musicology",
#   "Nanoscience and Nanotechnology",
#   "Nanotechnology fabrication",
#   "Natural Language Processing",
#   "Nature and Society Relations",
#   "Navigation, Guidance, Control and Dynamics",
#   "Near Eastern Languages and Societies",
#   "Nephrology",
#   "Networking and Internet Architecture",
#   "Neural and Evolutionary Computing",
#   "Neuroscience and Neurobiology",
#   "Non-linear Dynamics",
#   "Nonlinear Sciences",
#   "Nuclear",
#   "Nuclear Engineering",
#   "Nuclear Experiment",
#   "Nuclear Theory",
#   "Nuclear and Elementary Particle Physics, Quantum Mechanics, Relativity, Fields",
#   "Number Theory",
#   "Numerical Analysis and Computation",
#   "Numerical Analysis/Scientific Computing",
#   "Nursing Pharmacology, Toxicology and Environmental Health",
#   "Nutrition",
#   "Nutritional Epidemiology",
#   "Nutritional Sciences",
#   "OS/Networks",
#   "Ocean Engineering",
#   "Oceania Studies",
#   "Oceanography",
#   "Oceanography and Atmospheric Sciences and Meteorology",
#   "Operating Systems",
#   "Operating, Communication, Database and Distributed Systems",
#   "Operational Research",
#   "Operations Research, Systems Engineering and Industrial Engineering",
#   "Ophthalmology",
#   "Optics",
#   "Optics, Quantum Optics and Physics of Atoms, Molecules and Plasmas",
#   "Ordinary Differential Equations and Applied Dynamics",
#   "Organic Chemistry",
#   "Organic Molecular Chemistry - Synthesis and Characterisation",
#   "Organismic Interactions, Chemical Ecology and Microbiomes of Plant Systems",
#   "Organizational Communication",
#   "Orthopaedics, Traumatology, Reconstructive Surgery",
#   "Other Quantitative Biology",
#   "Other Statistics",
#   "Otolaryngology",
#   "Paleobiology",
#   "Paleontology",
#   "Parasitology",
#   "Partial Differential Equations",
#   "Particles, Nuclei and Fields",
#   "Pathogenic Microbiology",
#   "Pathology",
#   "Pattern Formation and Solitons",
#   "Pediatric and Adolescent Medicine",
#   "Performance Studies",
#   "Personality and Social Contexts",
#   "Petroleum Engineering",
#   "Pharmacology",
#   "Pharmacy",
#   "Philosophy",
#   "Philosophy of Language",
#   "Philosophy of Mind",
#   "Philosophy of Science",
#   "Phonetics/Phonology",
#   "Physical Chemistry",
#   "Physical Chemistry of Molecules, Liquids and Interfaces, Biophysical Chemistry",
#   "Physical Chemistry of Solids and Surfaces, Material Characterisation",
#   "Physical Processes",
#   "Physical Sciences & Mathematics",
#   "Physical and Environmental Geography",
#   "Physics",
#   "Physics Education",
#   "Physics and Society",
#   "Physiology",
#   "Place and Environment",
#   "Planetary Sciences",
#   "Plant Biochemistry and Biophysics",
#   "Plant Biology",
#   "Plant Breeding and Genetics",
#   "Plant Cell and Developmental Biology",
#   "Plant Cultivation, Plant Nutrition, Agricultural Technology",
#   "Plant Genetics",
#   "Plant Pathology",
#   "Plant Physiology",
#   "Plant Sciences",
#   "Plasma and Beam Physics",
#   "Plastics Engineering",
#   "Playwriting",
#   "Pneumology, Thoracic Surgery",
#   "Political History",
#   "Political Science",
#   "Political Theory",
#   "Politics and Social Change",
#   "Polymer Chemistry",
#   "Polymer Materials",
#   "Polymer Research",
#   "Polymer Science",
#   "Polymer and Organic Materials",
#   "Popular Physics",
#   "Population Biology",
#   "Portuguese Literature",
#   "Poultry (or Avian) Science",
#   "Power and Energy",
#   "Practical Philosophy",
#   "Preparatory and Physical Chemistry of Polymers",
#   "Primary Shaping and Reshaping Technology, Additive Manufacturing",
#   "Principles of Law and Jurisprudence",
#   "Private Law",
#   "Probability",
#   "Process Control and Systems",
#   "Process Engineering, Technical Chemistry",
#   "Production Automation",
#   "Production Systems, Operations Management, Quality Management and Factory  Planning",
#   "Production Technology",
#   "Programming Languages/Compilers",
#   "Propulsion and Power",
#   "Protestant Theology",
#   "Psycholinguistics/Neurolinguistics",
#   "Psychology",
#   "Psychology of Movement",
#   "Public Administration",
#   "Public Affairs",
#   "Public Affairs, Public Policy and Public Administration",
#   "Public Economics",
#   "Public Health",
#   "Public Health, Health Services Research, Social Medicine",
#   "Public Law",
#   "Public Policy",
#   "Public Relations/Advertising",
#   "Quantitative Finance",
#   "Quantitative Methods)",
#   "Quantum Algebra",
#   "Quantum Gases",
#   "Quantum Physics",
#   "Race and Ethnicity",
#   "Race, Ethnicity and post-Colonial Studies",
#   "Radiology, Nuclear Medicine, Radiotherapy, Radiobiology",
#   "Regional Sociology",
#   "Religion",
#   "Religious Studies and Jewish Studies",
#   "Religious Thought/Theology/Philosophy of Religion",
#   "Reproductive Medicine, Urology",
#   "Requirements Engineering",
#   "Rhetoric and Composition",
#   "Rheumatology",
#   "Robotics",
#   "Roman Catholic Theology",
#   "Rural sociology",
#   "Science and Technology Studies",
#   "Security and Dependability",
#   "Semantic Web",
#   "Semantics/Pragmatics",
#   "Semiconductor and Optical Materials",
#   "Sensory and Behavioural Biology",
#   "Set Theory",
#   "Signal Processing",
#   "Slavic Languages and Societies",
#   "Social Control, Law, Crime, and Deviance",
#   "Social History",
#   "Social Influence and Political Communication",
#   "Social Psychology",
#   "Social Psychology and Interaction",
#   "Social Sciences",
#   "Social and Behavioral Sciences",
#   "Social and Cultural",
#   "Social and Cultural Anthropology and Ethnology",
#   "Sociocentric networks",
#   "Sociological Theory",
#   "Sociology",
#   "Sociology of Culture",
#   "Soft Condensed Matter",
#   "Software Engineering",
#   "Software Engineering and Programming Languages",
#   "Soil Science",
#   "Solid State and Surface Chemistry, Material Synthesis",
#   "South and Southeast Asian Languages and Societies",
#   "Space Physics",
#   "Space Vehicles",
#   "Spanish Linguistics",
#   "Spanish Literature",
#   "Spanish and Portuguese Language and Literature",
#   "Speech and Rhetorical Studies",
#   "Stars, Interstellar Medium and the Galaxy",
#   "Statistical Methodology",
#   "Statistical Physics, Soft Matter, Biological Physics, Nonlinear Dynamics",
#   "Statistical Theory",
#   "Statistics and Probability",
#   "Structural Biology",
#   "Structural Engineering",
#   "Structural Engineering, Building Informatics and Construction Operation",
#   "Structural Materials",
#   "Structures and Materials",
#   "Subcellular Processes",
#   "Symplectic Geometry",
#   "Syntax",
#   "Synthesis and Properties of Functional Materials",
#   "Systematics and Morphology (Zoology)",
#   "Systems Biology",
#   "Systems Engineering",
#   "Systems Engineering and Multidisciplinary Design Optimization",
#   "Systems Neuroscience",
#   "Systems and Communications",
#   "Systems and Integrative Physiology",
#   "Systems and integrative engineering",
#   "Technical Chemistry",
#   "Technical Thermodynamics",
#   "Tectonics and Structure",
#   "Terrestrial and Aquatic Ecology",
#   "The Sun and the Solar System",
#   "Theatre History",
#   "Theatre and Media Studies",
#   "Theatre and Performance Studies",
#   "Theoretical Chemistry",
#   "Theoretical Chemistry: Electron Structure, Dynamics, Simulation",
#   "Theoretical Chemistry: Molecules, Materials, Surfaces",
#   "Theoretical Computer Science",
#   "Theoretical Condensed Matter Physics",
#   "Theoretical Philosophy",
#   "Theory and Criticism",
#   "Theory, Knowledge and Science",
#   "Theory/Algorithms",
#   "Thermodynamics",
#   "Thermodynamics and Kinetics as well as Properties of Phases and Microstructure of Materials",
#   "Tissues and Organs",
#   "Toxicology",
#   "Traffic and Transport Systems, Intelligent and Automated Traffic",
#   "Transport Phenomena",
#   "Tribology",
#   "Typological Linguistics and Linguistic Diversity",
#   "United States",
#   "Urban Studies",
#   "Urban Studies and Planning",
#   "Urbanism, Spatial Planning, Transportation and Infrastructure Planning, Landscape Planning",
#   "VLSI and circuits: Embedded/Hardware Systems",
#   "Veterinary Medical Sciene",
#   "Virology",
#   "Vulcanology",
#   "Water Research",
#   "Women\u2019s History",
#   "Wood Science and Pulp/Paper Technology",
#   "Work, Economy and Organizations",
#   "Zoology"
# ]

# %%
# Count subfields
subfield_count = {}

for inx, row in df.iterrows():
    for subfield in row["subfields"]:
        if subfield not in subfield_count:
            subfield_count[subfield] = 0

        subfield_count[subfield] += 1

print_json(subfield_count)
# Out:
# {
#   "Accelerator Physics": 3997,
#   "Acoustics, Dynamics, and Controls": 4114,
#   "Adaptation and Self-Organizing Systems": 3997,
#   "Aerodynamics and Fluid Mechanics": 4126,
#   "Aeronautical Vehicles": 4126,
#   "Aerospace Engineering": 4112,
#   "African": 4014,
#   "African Languages and Societies": 4014,
#   "African Studies": 4060,
#   "Agricultural Economics, Agricultural Policy, Agricultural Sociology": 4025,
#   "Agricultural and Resource Economics": 4058,
#   "Agriculture, Forestry and Veterinary Medicine": 4024,
#   "Agronomy and Crop Sciences": 4024,
#   "Algebra": 3994,
#   "Algebraic Geometry": 3994,
#   "Algebraic Topology": 3994,
#   "American Art and Architecture": 4014,
#   "American Film Studies": 4015,
#   "American Literature": 4015,
#   "American Material Culture": 4015,
#   "American Politics": 4058,
#   "American Popular Culture": 4015,
#   "American Studies": 4087,
#   "Anaesthesiology": 4038,
#   "Analysis": 3994,
#   "Analytical Chemistry": 4090,
#   "Anatomy": 4024,
#   "Ancient History (Greek and Roman through Late Antiquity)": 4015,
#   "Ancient Philosophy": 4015,
#   "Ancient, Medieval, Renaissance and Baroque Art and Architecture": 4014,
#   "Animal Breeding, Animal Nutrition, Animal Husbandry": 4025,
#   "Animal Physiology and Biochemistry": 4027,
#   "Animal Sciences": 4025,
#   "Anthropological Linguistics/Sociolinguistics": 4064,
#   "Applied Linguistics": 4064,
#   "Applied Mathematics": 3991,
#   "Applied Mechanics": 4114,
#   "Applied Mechanics, Statics and Dynamics": 4113,
#   "Applied Physics": 3997,
#   "Applied Statistics": 3992,
#   "Aquaculture and Fisheries": 4025,
#   "Archaeological": 4060,
#   "Architecture, Building and Construction History, Construction Research, Sustainable Building Technology": 4113,
#   "Art History": 4014,
#   "Artificial Intelligence": 13743,
#   "Arts and Humanities": 3987,
#   "Asian": 4014,
#   "Asian Art and Architecture": 4014,
#   "Asian Studies": 4060,
#   "Astrodynamics": 4126,
#   "Astrophysics and Astronomy": 3991,
#   "Atmospheric Sciences": 3993,
#   "Atomic Physics": 4111,
#   "Atomic and Molecular Clusters": 4111,
#   "Atomic, Molecular and Optical Physics": 3997,
#   "Audio and Speech Processing": 14469,
#   "Automation, Control Systems, Robotics, Mechatronics, Cyber Physical Systems": 4466,
#   "Bacteriology": 4032,
#   "Behavior and Ethology": 5404,
#   "Behavioral Economics": 4075,
#   "Behavioral Neurobiology": 4037,
#   "Biblical Studies": 4015,
#   "Biochemical and Biomolecular Engineering": 4113,
#   "Biochemistry": 4138,
#   "Biochemistry, Biophysics, and Structural Biology": 4024,
#   "Bioelectrical and neuroengineering": 4120,
#   "Biogeochemistry": 5527,
#   "Biogerontology and Geriatric Medicine": 4038,
#   "Bioimaging and biomedical optics": 4120,
#   "Bioinformatics": 4024,
#   "Biological Chemistry and Food Chemistry": 4090,
#   "Biological Engineering": 4120,
#   "Biological Process Engineering": 4090,
#   "Biological Psychiatry": 4037,
#   "Biological Psychology": 4093,
#   "Biological and Biomimetic Chemistry": 4090,
#   "Biological and Chemical Physics": 3997,
#   "Biological and Physical": 4060,
#   "Biology and Biomimetic Materials": 4237,
#   "Biology/Integrated Biology/ Integrated Biomedical Sciences": 4024,
#   "Biomaterials": 4245,
#   "Biomechanical Engineering": 4114,
#   "Biomechanics": 4026,
#   "Biomechanics and biotransport": 4120,
#   "Biomedical": 4112,
#   "Biomedical Engineering and Bioengineering": 4112,
#   "Biomedical Systems Technology": 4466,
#   "Biomedical devices and instrumentation": 4120,
#   "Biometry": 3992,
#   "Biomolecules": 4058,
#   "Biophysics": 4035,
#   "Biostatistics": 4037,
#   "Biotechnology": 4024,
#   "Botany": 5404,
#   "Broadcast/Video Studies": 4059,
#   "Business Administration": 4075,
#   "Byzantine and Modern Greek": 4015,
#   "Cancer Biology": 4024,
#   "Cardiac and Vascular Sugery": 4038,
#   "Cardiology, Angiology": 4038,
#   "Catalysis and Reaction Engineering": 4113,
#   "Category Theory": 3994,
#   "Cell Behavior": 4030,
#   "Cell Biology": 4024,
#   "Cell and Developmental Biology": 4024,
#   "Cellular Automata and Lattice Gases": 3997,
#   "Cellular and Molecular Physiology": 4025,
#   "Ceramic Materials": 4237,
#   "Chaotic Dynamics": 3997,
#   "Chemical Engineering": 4112,
#   "Chemical Solid State and Surface Research": 3991,
#   "Chemical and Thermal Process Engineering": 4090,
#   "Chemistry": 3991,
#   "Civil Engineering": 4113,
#   "Civil and Environmental Engineering": 4112,
#   "Classical Archaeology and Art History": 4015,
#   "Classical Literature and Philology": 4015,
#   "Classical Physics": 3997,
#   "Classics": 4014,
#   "Climate": 3993,
#   "Clinical Immunology and Allergology": 4038,
#   "Clinical Infectiology and Tropical Medicine": 4038,
#   "Clinical Neurology; Neurosurgery and Neuroradiology": 4037,
#   "Clinical Psychiatry, Psychotherapy, Child and Adolescent Psychiatry": 4037,
#   "Coating and Surface Technology": 4112,
#   "Cognition and Perception": 4093,
#   "Cognitive Neuroscience": 4037,
#   "Cognitive Psychology": 4093,
#   "Communication Neuroscience": 4109,
#   "Communication Sciences": 4058,
#   "Communication Technology and New Media": 4059,
#   "Communications, High-Frequency and Network Technology, Theoretical Electrical Engineering": 4120,
#   "Community Psychology": 4093,
#   "Commutative Algebra": 3995,
#   "Comparative Literature": 4014,
#   "Comparative Methodologies and Theories": 4015,
#   "Comparative Nutrition": 4024,
#   "Comparative Politics": 4058,
#   "Comparative and Evolutionary Physiology": 4025,
#   "Comparative and Historical Linguistics": 4064,
#   "Complex Fluids": 4113,
#   "Complex Variables": 3994,
#   "Composition": 4014,
#   "Computational Biology": 4025,
#   "Computational Complexity": 13763,
#   "Computational Engineering": 4112,
#   "Computational Geometry": 13763,
#   "Computational Linguistics": 4064,
#   "Computational Neuroscience": 4037,
#   "Computational Physics": 3997,
#   "Computer Architecture and Embedded Systems": 13743,
#   "Computer Engineering": 4112,
#   "Computer Science General Literature": 13743,
#   "Computer Science and Game Theory": 13743,
#   "Computer Sciences": 3991,
#   "Computer Vision and Pattern Recognition": 13743,
#   "Computer and Systems Architecture": 14183,
#   "Computer-Aided Design of Materials and Simulation of Materials Behaviour from  Atomic to Microscopic Scale": 4237,
#   "Computer-Aided Engineering and Design": 4114,
#   "Computers and Society": 13743,
#   "Condensed Matter Physics": 3997,
#   "Construction Engineering/management": 4113,
#   "Construction Material Sciences, Chemistry, Building Physics": 4113,
#   "Contemporary Art": 4014,
#   "Continental Philosophy": 4015,
#   "Control Theory": 3992,
#   "Controls and Control Theory": 4112,
#   "Cosmochemistry": 4099,
#   "Cosmology": 4018,
#   "Cosmology, Relativity, and Gravity": 3997,
#   "Criminal Law": 4061,
#   "Criminology": 4061,
#   "Critical and Cultural Studies": 4059,
#   "Cryptography and Security": 13743,
#   "Cultural History": 4014,
#   "Dairy Science": 4025,
#   "Data Analysis, Statistics and Probability": 3998,
#   "Data Storage Systems": 4428,
#   "Databases/Information Systems": 13743,
#   "Demography, Population, and Ecology": 4078,
#   "Dentistry, Oral Surgery": 4038,
#   "Dermatology": 4038,
#   "Developmental Biology": 4024,
#   "Developmental Neurobiology": 4037,
#   "Developmental Neuroscience": 4037,
#   "Developmental Psychology": 4093,
#   "Developmental and Educational Psychology": 4093,
#   "Differential Geometry": 3994,
#   "Differential, Clinical and Medical Psychology, Methodology": 4093,
#   "Digital Circuits": 4428,
#   "Digital Communications and Networking": 4428,
#   "Digital Libraries": 13855,
#   "Diplomatic History": 4014,
#   "Discourse/Text Linguistics": 4064,
#   "Discrete Mathematics and Combinatorics": 3994,
#   "Disordered Systems and Neural Networks": 3998,
#   "Dramatic Literature, Criticism and Theory": 4015,
#   "Dynamic Systems": 3992,
#   "Dynamics/Dynamical Systems": 3994,
#   "Early Modern History": 4014,
#   "Earth Sciences": 3991,
#   "East Asian Languages and Societies": 4014,
#   "Ecology and Biodiversity of Animals and Ecosystems, Organismic Interactions": 4027,
#   "Ecology and Biodiversity of Plants and Ecosystems": 4024,
#   "Ecology and Evolutionary Biology": 4024,
#   "Ecology of Land Use": 4025,
#   "Econometrics": 4075,
#   "Economic History": 4075,
#   "Economic Policy, Applied Economics": 4075,
#   "Economic Theory": 4075,
#   "Economics": 4058,
#   "Education Systems and Educational Institutions": 4176,
#   "Educational Research": 4014,
#   "Educational Research on Socialization, Welfare and Professionalism Research": 4176,
#   "Ego-centric networks": 5,
#   "Egyptology and Ancient Near Eastern Studies": 4014,
#   "Electrical Energy Generation, Distribution, Application": 4120,
#   "Electrical Engineering and Information Technology": 4112,
#   "Electrical and Computer Engineering": 4112,
#   "Electrical and Electronics": 4112,
#   "Electro-Mechanical Systems": 4114,
#   "Electromagnetics and photonics": 4112,
#   "Electronic Devices and Semiconductor Manufacturing": 4112,
#   "Electronic Semiconductors, Components, Circuits, Systems": 4120,
#   "Elementary Particles and Fields and String Theory": 3997,
#   "Empirical Social Research": 4070,
#   "Endocrinology": 4025,
#   "Energy Process Engineering": 4118,
#   "Energy Systems": 4114,
#   "Engineering": 3987,
#   "Engineering Design, Machine Elements, Product Development": 4114,
#   "Engineering Mechanics": 4112,
#   "Engineering Physics": 3997,
#   "Engineering Science and Materials (not elsewhere classified)": 4112,
#   "English Language and Literature": 4014,
#   "Entomology Food Science": 4024,
#   "Environmental Chemistry": 4090,
#   "Environmental Engineering": 4113,
#   "Environmental Health": 4032,
#   "Environmental Microbiology and Microbial Ecology": 4032,
#   "Environmental Sciences": 4099,
#   "Epidemiology": 4032,
#   "Epidemiology and Medical Biometry/Statistics": 4038,
#   "Epistemology": 4015,
#   "Ergonomics": 4462,
#   "Esthetics": 4015,
#   "Ethics": 4015,
#   "Ethics and Political Philosophy": 4015,
#   "Ethnic Studies": 4015,
#   "Ethnomusicology": 4014,
#   "European": 4014,
#   "European Languages and Societies (not elsewhere classified)": 4014,
#   "European Literature": 4015,
#   "Evolution": 5404,
#   "Evolution and Systematics of Plants and Fungi": 4024,
#   "Evolution, Anthropology": 4027,
#   "Exactly Solvable and Integrable Systems": 3997,
#   "Exercise Physiology": 4027,
#   "Experimental Condensed Matter Physics": 3998,
#   "Experimental Models for the Understanding of Nervous System Diseases": 4037,
#   "Experimental and Theoretical Network Neuroscience": 4037,
#   "Experimental and Theoretical Physics of Polymers": 3991,
#   "External Galaxies": 4018,
#   "Family, Life Course, and Society": 4078,
#   "Feminist Philosophy": 4015,
#   "Feminist, Gender and Sexuality Studies": 4016,
#   "Feminist, Gender, and Sexuality Studies": 4014,
#   "Film Studies": 4014,
#   "First/Second Language Acquisition": 4064,
#   "Fluid Dynamics": 3997,
#   "Fluid Mechanics": 4118,
#   "Fluid Mechanics, Technical Thermodynamics and Thermal Energy Engineering": 4118,
#   "Food Biotechnology": 4026,
#   "Food Chemistry": 4129,
#   "Food Microbiology": 4026,
#   "Food Processing": 4026,
#   "Forest Biology": 4024,
#   "Forest Management": 4024,
#   "Forestry and Forest Sciences": 4024,
#   "French Linguistics": 4015,
#   "French and Francophone Language and Literature": 4015,
#   "French and Francophone Literature": 4015,
#   "Fresh Water Studies": 3993,
#   "Gastroenterology": 4038,
#   "Gender": 4014,
#   "Gender and Sexuality": 4078,
#   "Gender, Race, Sexuality, and Ethnicity in Communication": 4059,
#   "General Education and History of Education": 4176,
#   "General Physics": 3997,
#   "General Topology": 3994,
#   "General and Domain-Specific Teaching and Learning": 4176,
#   "General and Visceral Surgery": 4038,
#   "General, Cognitive and Mathematical Psychology": 4093,
#   "Genetics": 4025,
#   "Genetics and Genomics": 4024,
#   "Genomics": 4025,
#   "Geochemistry": 4099,
#   "Geodesy, Photogrammetry, Remote Sensing, Geoinformatics, Cartography": 3997,
#   "Geographic Information Sciences": 4061,
#   "Geography": 4058,
#   "Geology": 4099,
#   "Geometry and Topology": 3994,
#   "Geophysics": 4109,
#   "Geophysics and Geodesy": 3997,
#   "Geophysics and Seismology": 4099,
#   "Geotechnical Engineering": 4113,
#   "Geotechnics, Hydraulic Engineering": 4113,
#   "German Language and Literature": 4015,
#   "German Linguistics": 4015,
#   "German Literature": 4015,
#   "Glaciology": 4099,
#   "Glass, Ceramics and Derived Composites": 4112,
#   "Graphics": 13743,
#   "Growth and Development": 4075,
#   "Gynaecology and Obstetrics": 4038,
#   "Hardware Systems": 4428,
#   "Harmonic Analysis and Representation": 3994,
#   "Health Communication": 4059,
#   "Health Psychology": 4093,
#   "Heat Transfer, Combustion": 4114,
#   "Hematology, Oncology": 4038,
#   "History": 4014,
#   "History and Philosophy of Physics": 3997,
#   "History of Art, Architecture and Archaeology": 4014,
#   "History of Philosophy": 4015,
#   "History of Religion": 4014,
#   "History of Religions of Eastern Origins": 4015,
#   "History of Religions of Western Origin": 4015,
#   "History of Science, Technology, and Medicine": 4014,
#   "Horticulture": 4024,
#   "Human Computer Interfaces": 13743,
#   "Human Factors, Ergonomics, Human-Machine Systems": 4466,
#   "Human Genetics": 4038,
#   "Human Geography": 4061,
#   "Human and Clinical Nutrition": 4024,
#   "Hydraulic and Turbo Engines and Piston Engines": 4118,
#   "Hydrogeology, Hydrology, Limnology, Urban Water Management, Water Chemistry, Integrated Water Resources Management": 3991,
#   "Image and Video Processing": 14469,
#   "Immunity": 4039,
#   "Immunology and Infectious Disease": 4024,
#   "Immunology of Infectious Disease": 4039,
#   "Immunopathology": 4039,
#   "Immunoprophylaxis and Therapy": 4039,
#   "Individual Linguistics": 4064,
#   "Indo-European Linguistics and Philology": 4015,
#   "Industrial Engineering": 4462,
#   "Industrial Organization": 4075,
#   "Industrial and Organizational Psychology": 4093,
#   "Inequality and Stratification": 4078,
#   "Information Science": 4112,
#   "Information Systems, Process and Knowledge Management": 13743,
#   "Information Theory": 13763,
#   "Inorganic Chemistry": 4090,
#   "Inorganic Molecular Chemistry - Synthesis and Characterisation": 4090,
#   "Instrumentation": 4018,
#   "Intellectual History": 4014,
#   "Interactive and Intelligent Systems, Image and Language Processing, Computer Graphics and Visualisation": 13743,
#   "International Economics": 4075,
#   "International Relations": 4058,
#   "International and Community Nutrition": 4024,
#   "International and Intercultural Communication": 4059,
#   "Interpersonal/Small Group Communication": 4059,
#   "Islamic Studies, Arabian Studies, Semitic Studies": 4060,
#   "Islamic World/Near East": 4014,
#   "Joining and Separation Technology": 4112,
#   "Journalism Studies": 4059,
#   "Jurisprudence": 4058,
#   "Labor Economics": 4075,
#   "Language Description/Documentation": 4064,
#   "Language, Societies, and Cultures": 4014,
#   "Latin American": 4014,
#   "Latin American Languages and Societies (not elsewhere classified": 4014,
#   "Latin American Literature": 4015,
#   "Learner-Interface Interaction": 14469,
#   "Legal": 4014,
#   "Life Sciences": 3987,
#   "Lightweight Construction, Textile Technology": 4114,
#   "Linguistic Anthrolpology": 4060,
#   "Linguistics": 4058,
#   "Literary Studies": 4014,
#   "Literature in English, Anglophone (other than British Isles and North America)": 4016,
#   "Literature in English, British Isles": 4016,
#   "Literature in English, North America (other than ethnic and minority)": 4016,
#   "Literature in English, North America, ethnic and minority": 4016,
#   "Logic and Foundations": 3994,
#   "Logic and foundations of mathematics": 4015,
#   "Logic in Computer Science": 13763,
#   "Machine Learning": 14469,
#   "Macroeconomics": 4075,
#   "Manufacturing": 4114,
#   "Mass Communication": 4059,
#   "Massively Parallel and Data-Intensive Systems": 13743,
#   "Materials Chemistry": 4090,
#   "Materials Engineering": 4112,
#   "Materials Science and Engineering": 4112,
#   "Materials in Sintering Processes and Generative Manufacturing Processes": 4112,
#   "Mathematical Software": 3994,
#   "Mathematics": 3991,
#   "Mathematics History and Overview": 3994,
#   "Measurement Systems": 4466,
#   "Mechanical Engineering": 4112,
#   "Mechanical Process Engineering": 4090,
#   "Mechanical Properties of Metallic Materials and their Microstructural Origins": 4112,
#   "Mechanics": 4114,
#   "Mechanics and Constructive Mechanical Engineering": 4114,
#   "Mechanics of Materials": 4112,
#   "Medical Informatics and Medical Bioinformatics": 4038,
#   "Medical Microbiology and Mycology, Hygiene, Molecular Infection Biology": 4032,
#   "Medical Physics": 3997,
#   "Medical Physics, Biomedical Technology": 4038,
#   "Medicinal Chemistry and Pharmaceutics": 4024,
#   "Medicinal-Pharmaceutical Chemistry": 4090,
#   "Medicine": 4024,
#   "Medicine and Health": 4078,
#   "Medieval German Literature": 4017,
#   "Medieval History": 4014,
#   "Membrane Science": 4113,
#   "Mesoscale and Nanoscale Physics": 3998,
#   "Metabolism, Biochemistry and Genetics of Microorganisms": 4032,
#   "Metal-Cutting and Abrasive Manufacturing Engineering": 4112,
#   "Metallurgical, Thermal and Thermomechanical Treatment of Materials": 4112,
#   "Metallurgy": 4237,
#   "Metaphysics": 4015,
#   "Meteorology": 3993,
#   "Methodologies : Quantitative, Qualitative, Comparative, and Historical": 4078,
#   "Metric Geometry": 3994,
#   "Microbial Ecology and Applied Microbiology": 4032,
#   "Microbial Physiology": 4032,
#   "Microbiology": 4024,
#   "Microsystems": 4466,
#   "Military History": 4014,
#   "Mineral Physics": 4099,
#   "Mineralogy, Petrology and Geochemistry": 3991,
#   "Models and Methods": 4058,
#   "Modern Art and Architecture": 4014,
#   "Modern German Literature": 4017,
#   "Modern and Current History": 4014,
#   "Molecular Biology": 4035,
#   "Molecular Chemistry": 4090,
#   "Molecular and Cellular Neurology and Neuropathology": 4037,
#   "Molecular and Cellular Neuroscience": 4037,
#   "Molecular genetics": 4025,
#   "Molecular, Genetic, and Biochemical Nutrition": 4024,
#   "Molecular, cellular, and tissue engineering": 4120,
#   "Morphology": 4064,
#   "Motor Control": 4026,
#   "Multi-Vehicle Systems and Air Traffic Control": 4126,
#   "Multiagent Systems": 14469,
#   "Music Theory": 4014,
#   "Musicology": 4014,
#   "Nanoscience and Nanotechnology": 4112,
#   "Nanotechnology fabrication": 4112,
#   "Natural Language Processing": 14469,
#   "Nature and Society Relations": 4061,
#   "Navigation, Guidance, Control and Dynamics": 4126,
#   "Near Eastern Languages and Societies": 4014,
#   "Nephrology": 4038,
#   "Networking and Internet Architecture": 13743,
#   "Neural and Evolutionary Computing": 14469,
#   "Neuroscience and Neurobiology": 4024,
#   "Non-linear Dynamics": 4121,
#   "Nonlinear Sciences": 3997,
#   "Nuclear": 3997,
#   "Nuclear Engineering": 4112,
#   "Nuclear Experiment": 3997,
#   "Nuclear Theory": 3997,
#   "Nuclear and Elementary Particle Physics, Quantum Mechanics, Relativity, Fields": 3991,
#   "Number Theory": 3994,
#   "Numerical Analysis and Computation": 3992,
#   "Numerical Analysis/Scientific Computing": 13743,
#   "Nursing Pharmacology, Toxicology and Environmental Health": 4024,
#   "Nutrition": 4024,
#   "Nutritional Epidemiology": 4024,
#   "Nutritional Sciences": 4038,
#   "OS/Networks": 13743,
#   "Ocean Engineering": 4114,
#   "Oceania Studies": 4060,
#   "Oceanography": 3993,
#   "Oceanography and Atmospheric Sciences and Meteorology": 3991,
#   "Operating Systems": 13743,
#   "Operating, Communication, Database and Distributed Systems": 13743,
#   "Operational Research": 4462,
#   "Operations Research, Systems Engineering and Industrial Engineering": 4112,
#   "Ophthalmology": 4037,
#   "Optics": 3997,
#   "Optics, Quantum Optics and Physics of Atoms, Molecules and Plasmas": 3991,
#   "Ordinary Differential Equations and Applied Dynamics": 3992,
#   "Organic Chemistry": 4090,
#   "Organic Molecular Chemistry - Synthesis and Characterisation": 4090,
#   "Organismic Interactions, Chemical Ecology and Microbiomes of Plant Systems": 4024,
#   "Organizational Communication": 4059,
#   "Orthopaedics, Traumatology, Reconstructive Surgery": 4038,
#   "Other Quantitative Biology": 4026,
#   "Other Statistics": 3992,
#   "Otolaryngology": 4038,
#   "Paleobiology": 4099,
#   "Paleontology": 4099,
#   "Parasitology": 4039,
#   "Partial Differential Equations": 3992,
#   "Particles, Nuclei and Fields": 3991,
#   "Pathogenic Microbiology": 4032,
#   "Pathology": 4039,
#   "Pattern Formation and Solitons": 3997,
#   "Pediatric and Adolescent Medicine": 4038,
#   "Performance Studies": 4015,
#   "Personality and Social Contexts": 4093,
#   "Petroleum Engineering": 4113,
#   "Pharmacology": 4024,
#   "Pharmacy": 4038,
#   "Philosophy": 4014,
#   "Philosophy of Language": 4015,
#   "Philosophy of Mind": 4015,
#   "Philosophy of Science": 4015,
#   "Phonetics/Phonology": 4064,
#   "Physical Chemistry": 4090,
#   "Physical Chemistry of Molecules, Liquids and Interfaces, Biophysical Chemistry": 4109,
#   "Physical Chemistry of Solids and Surfaces, Material Characterisation": 3991,
#   "Physical Processes": 4018,
#   "Physical Sciences & Mathematics": 3987,
#   "Physical and Environmental Geography": 4061,
#   "Physics": 3991,
#   "Physics Education": 3997,
#   "Physics and Society": 4078,
#   "Physiology": 4024,
#   "Place and Environment": 4078,
#   "Planetary Sciences": 4018,
#   "Plant Biochemistry and Biophysics": 4024,
#   "Plant Biology": 4024,
#   "Plant Breeding and Genetics": 4024,
#   "Plant Cell and Developmental Biology": 4024,
#   "Plant Cultivation, Plant Nutrition, Agricultural Technology": 4025,
#   "Plant Genetics": 4024,
#   "Plant Pathology": 4024,
#   "Plant Physiology": 4024,
#   "Plant Sciences": 4024,
#   "Plasma and Beam Physics": 3997,
#   "Plastics Engineering": 4112,
#   "Playwriting": 4015,
#   "Pneumology, Thoracic Surgery": 4038,
#   "Political History": 4014,
#   "Political Science": 4058,
#   "Political Theory": 4058,
#   "Politics and Social Change": 4078,
#   "Polymer Chemistry": 4090,
#   "Polymer Materials": 3991,
#   "Polymer Research": 3991,
#   "Polymer Science": 4113,
#   "Polymer and Organic Materials": 4237,
#   "Popular Physics": 3997,
#   "Population Biology": 5404,
#   "Portuguese Literature": 4015,
#   "Poultry (or Avian) Science": 4025,
#   "Power and Energy": 4112,
#   "Practical Philosophy": 4015,
#   "Preparatory and Physical Chemistry of Polymers": 3991,
#   "Primary Shaping and Reshaping Technology, Additive Manufacturing": 4112,
#   "Principles of Law and Jurisprudence": 4061,
#   "Private Law": 4061,
#   "Probability": 3992,
#   "Process Control and Systems": 4113,
#   "Process Engineering, Technical Chemistry": 4090,
#   "Production Automation": 4112,
#   "Production Systems, Operations Management, Quality Management and Factory  Planning": 4112,
#   "Production Technology": 4112,
#   "Programming Languages/Compilers": 13743,
#   "Propulsion and Power": 4126,
#   "Protestant Theology": 4015,
#   "Psycholinguistics/Neurolinguistics": 4064,
#   "Psychology": 4058,
#   "Psychology of Movement": 4026,
#   "Public Administration": 4059,
#   "Public Affairs": 4059,
#   "Public Affairs, Public Policy and Public Administration": 4058,
#   "Public Economics": 4075,
#   "Public Health": 4024,
#   "Public Health, Health Services Research, Social Medicine": 4038,
#   "Public Law": 4061,
#   "Public Policy": 4059,
#   "Public Relations/Advertising": 4059,
#   "Quantitative Finance": 4075,
#   "Quantitative Methods)": 4026,
#   "Quantum Algebra": 3995,
#   "Quantum Gases": 3997,
#   "Quantum Physics": 3997,
#   "Race and Ethnicity": 4078,
#   "Race, Ethnicity and post-Colonial Studies": 4014,
#   "Radiology, Nuclear Medicine, Radiotherapy, Radiobiology": 4038,
#   "Regional Sociology": 4078,
#   "Religion": 4014,
#   "Religious Studies and Jewish Studies": 4060,
#   "Religious Thought/Theology/Philosophy of Religion": 4015,
#   "Reproductive Medicine, Urology": 4038,
#   "Requirements Engineering": 14414,
#   "Rhetoric and Composition": 4016,
#   "Rheumatology": 4038,
#   "Robotics": 4428,
#   "Roman Catholic Theology": 4015,
#   "Rural sociology": 4078,
#   "Science and Technology Studies": 4058,
#   "Security and Dependability": 13743,
#   "Semantic Web": 13855,
#   "Semantics/Pragmatics": 4064,
#   "Semiconductor and Optical Materials": 4237,
#   "Sensory and Behavioural Biology": 4027,
#   "Set Theory": 3994,
#   "Signal Processing": 4112,
#   "Slavic Languages and Societies": 4014,
#   "Social Control, Law, Crime, and Deviance": 4078,
#   "Social History": 4014,
#   "Social Influence and Political Communication": 4059,
#   "Social Psychology": 4093,
#   "Social Psychology and Interaction": 4078,
#   "Social Sciences": 4058,
#   "Social and Behavioral Sciences": 3987,
#   "Social and Cultural": 4060,
#   "Social and Cultural Anthropology and Ethnology": 4058,
#   "Sociocentric networks": 5,
#   "Sociological Theory": 4070,
#   "Sociology": 4058,
#   "Sociology of Culture": 4078,
#   "Soft Condensed Matter": 3998,
#   "Software Engineering": 13743,
#   "Software Engineering and Programming Languages": 13743,
#   "Soil Science": 4099,
#   "Solid State and Surface Chemistry, Material Synthesis": 4090,
#   "South and Southeast Asian Languages and Societies": 4014,
#   "Space Physics": 3997,
#   "Space Vehicles": 4126,
#   "Spanish Linguistics": 4015,
#   "Spanish Literature": 4015,
#   "Spanish and Portuguese Language and Literature": 4015,
#   "Speech and Rhetorical Studies": 4059,
#   "Stars, Interstellar Medium and the Galaxy": 4018,
#   "Statistical Methodology": 3992,
#   "Statistical Physics, Soft Matter, Biological Physics, Nonlinear Dynamics": 3991,
#   "Statistical Theory": 3992,
#   "Statistics and Probability": 3991,
#   "Structural Biology": 4035,
#   "Structural Engineering": 4113,
#   "Structural Engineering, Building Informatics and Construction Operation": 4113,
#   "Structural Materials": 4237,
#   "Structures and Materials": 4126,
#   "Subcellular Processes": 4121,
#   "Symplectic Geometry": 3994,
#   "Syntax": 4064,
#   "Synthesis and Properties of Functional Materials": 4237,
#   "Systematics and Morphology (Zoology)": 4027,
#   "Systems Biology": 4024,
#   "Systems Engineering": 4462,
#   "Systems Engineering and Multidisciplinary Design Optimization": 4126,
#   "Systems Neuroscience": 4037,
#   "Systems and Communications": 4112,
#   "Systems and Integrative Physiology": 4025,
#   "Systems and integrative engineering": 4120,
#   "Technical Chemistry": 4090,
#   "Technical Thermodynamics": 4118,
#   "Tectonics and Structure": 4099,
#   "Terrestrial and Aquatic Ecology": 5404,
#   "The Sun and the Solar System": 4018,
#   "Theatre History": 4015,
#   "Theatre and Media Studies": 4014,
#   "Theatre and Performance Studies": 4014,
#   "Theoretical Chemistry": 4090,
#   "Theoretical Chemistry: Electron Structure, Dynamics, Simulation": 4090,
#   "Theoretical Chemistry: Molecules, Materials, Surfaces": 4090,
#   "Theoretical Computer Science": 13743,
#   "Theoretical Condensed Matter Physics": 3998,
#   "Theoretical Philosophy": 4015,
#   "Theory and Criticism": 4014,
#   "Theory, Knowledge and Science": 4078,
#   "Theory/Algorithms": 13743,
#   "Thermodynamics": 4113,
#   "Thermodynamics and Kinetics as well as Properties of Phases and Microstructure of Materials": 4237,
#   "Tissues and Organs": 4121,
#   "Toxicology": 4024,
#   "Traffic and Transport Systems, Intelligent and Automated Traffic": 4466,
#   "Transport Phenomena": 4113,
#   "Tribology": 4114,
#   "Typological Linguistics and Linguistic Diversity": 4064,
#   "United States": 4014,
#   "Urban Studies": 4059,
#   "Urban Studies and Planning": 4058,
#   "Urbanism, Spatial Planning, Transportation and Infrastructure Planning, Landscape Planning": 4113,
#   "VLSI and circuits: Embedded/Hardware Systems": 4112,
#   "Veterinary Medical Sciene": 4025,
#   "Virology": 4032,
#   "Vulcanology": 4099,
#   "Water Research": 3991,
#   "Women\u2019s History": 4014,
#   "Wood Science and Pulp/Paper Technology": 4024,
#   "Work, Economy and Organizations": 4078,
#   "Zoology": 4025
# }
